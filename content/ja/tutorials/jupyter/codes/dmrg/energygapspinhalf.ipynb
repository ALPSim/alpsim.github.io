# %% [markdown]
# ## Energy Gap of a Spin-1/2 Chain

# %% [markdown]
# In this tutorial, we will calculate the energy gap of a 32-site spin-1/2 chain using DMRG simulations. The gap, as one knows, approaches 0 in the thermodynamic limit for a spin-1/2 chain.
#
# The calculation can be done by two methods. The first method is through the direct calculation of both the ground state and the first excited state energies in the same DMRG simulation. The difference of the two energies gives the energy gap. The second method is through the calculation of two ground state energy in two spin sectors: singlet and triplet spin sectors, by fixing the total spin magnetization to either 0 or 1.

# %% [markdown]
# ### Method 1: Direct Calculation of Ground-state and Excited-state Energies

# %% [markdown]
# We first load the necessary libraries and prepare the input parameters.

# %%
import pyalps
import numpy as np

parms = [ { 
        'LATTICE'                   : "open chain lattice", 
        'MODEL'                     : "spin",
        'CONSERVED_QUANTUMNUMBERS'  : 'Sz',
        'Sz_total'                  : 0,
        'J'                         : 1,
        'SWEEPS'                    : 4,
        'L'                         : 32,
        'MAXSTATES'                 : 100,
        'NUMBER_EIGENVALUES'        : 2
       } ]

# %% [markdown]
# Note that the `NUMBER_EIGENVALUES = 2`, meaning the ground state and the first excited state energies will be kept in the simulation.
#
# We then write the input file and run the simulation.

# %%
input_file = pyalps.writeInputFiles('parm_spin_one_half_gap',parms)
res = pyalps.runApplication('dmrg',input_file,writexml=True)
# Out:
# dmrg parm_spin_one_half_gap.in.xml --write-xml
# ALPS DMRG temporary files will be written to .
# ALPS/dmrg version 1.0.0 (2006/10/02)
#   Density Matrix Renormalization Group algorithm
#   for low-dimensional interacting systems.
#   available from http://alps.comp-phys.org/
#   copyright (c) 2006-2013 by Adrian E. Feiguin
#   for details see the publication:
#   A.F. Albuquerque et al., J. of Magn. and Magn. Materials 310, 1187 (2007).
#
# using the ALPS parallelizing scheduler
#   copyright (c) 1994-2006 by Matthias Troyer <troyer@comp-phys.org>.
#   see Lecture Notes in Computer Science, Vol. 1505, p. 191 (1998).
#
# based on the ALPS libraries version 2.3.0
#   available from http://alps.comp-phys.org/
#   copyright (c) 1994-2016 by the ALPS collaboration.
#   Consult the web page for license details.
#   For details see the publication:
#   B. Bauer et al., J. Stat. Mech. (2011) P05001.
#
# parsing task files ...
# ALPS DMRG temporary files will be written to /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/
# ALPS DMRG temporary files will be written to /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/
# Starting task 1.
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_1_lN8mB1j
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_1_rgtTdxN
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/iter_ALPSUL11Lk
# LEFT-TO-RIGHT sweep to get B(1)B(2)...B(L/2-1)
# WARMUP LEFT-TO-RIGHT ITERATION 1
# NUMBER OF STATES: 2 2 2 2 6
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/vectors_ALPSGUtFhy
# E0 = -1.61596972775
# E0 = -0.956836195956
# EXCITED OVERLAP(0) = 1.37127944999e-07
# E(1) = -0.956836195961
# GAP(1) = -1.61596972775 -0.956836195961 0.659133531794
# ITER = 1 ENTROPY = 0.517253867115
# -------------------------------------------
# Truncation error = 2.08166817117e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/systemUT8RMg
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_2_l8deBmA
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_2_lUF54xc
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_1_l85OMs7
# WARMUP LEFT-TO-RIGHT ITERATION 2
# NUMBER OF STATES: 4 2 2 2 10
# E0 = -1.92788621219
# E0 = -1.2027244108
# EXCITED OVERLAP(0) = -6.9320267613e-06
# E(1) = -1.2027244108
# GAP(1) = -1.92788621219 -1.2027244108 0.725161801387
# ITER = 2 ENTROPY = 0.675080798308
# -------------------------------------------
# Truncation error = -1.11022302463e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_3_lEkBKrC
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_3_lBFoT86
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_2_lVrABGk
# WARMUP LEFT-TO-RIGHT ITERATION 3
# NUMBER OF STATES: 8 2 2 2 20
# E0 = -2.49357713236
# E0 = -2.0019953484
# EXCITED OVERLAP(0) = 2.56153431799e-12
# E(1) = -2.00199534839
# GAP(1) = -2.49357713236 -2.00199534839 0.491581783979
# ITER = 3 ENTROPY = 0.629985384572
# -------------------------------------------
# Truncation error = 2.77555756156e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_4_l6eSyiA
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_4_lXCB7FW
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_3_lXmpTao
# WARMUP LEFT-TO-RIGHT ITERATION 4
# NUMBER OF STATES: 16 2 2 2 35
# E0 = -2.83623967889
# E0 = -2.27881970769
# EXCITED OVERLAP(0) = 2.98661486098e-08
# E(1) = -2.27881970769
# GAP(1) = -2.83623967889 -2.27881970769 0.557419971207
# ITER = 4 ENTROPY = 0.719562681192
# -------------------------------------------
# Truncation error = -6.93889390391e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_5_lBi4t3s
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_5_lLR6tlx
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_4_ljdEhcg
# WARMUP LEFT-TO-RIGHT ITERATION 5
# NUMBER OF STATES: 20 2 2 2 43
# E0 = -3.37084967186
# E0 = -2.96511548972
# EXCITED OVERLAP(0) = -7.72651387315e-12
# E(1) = -2.96511548973
# GAP(1) = -3.37084967186 -2.96511548973 0.405734182122
# ITER = 5 ENTROPY = 0.666971978696
# -------------------------------------------
# Truncation error = -9.02056207508e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_6_l64hiK6
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_6_lCIZMOi
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_5_litCXrG
# WARMUP LEFT-TO-RIGHT ITERATION 6
# NUMBER OF STATES: 20 2 2 2 48
# E0 = -3.73364291019
# E0 = -3.2504991957
# EXCITED OVERLAP(0) = 1.04804220857e-10
# E(1) = -3.2504991957
# GAP(1) = -3.73364291019 -3.2504991957 0.483143714493
# ITER = 6 ENTROPY = 0.737202825424
# -------------------------------------------
# Truncation error = -2.91433543964e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_7_lxlaMeB
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_7_lukre1n
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_6_lTLzmz8
# WARMUP LEFT-TO-RIGHT ITERATION 7
# NUMBER OF STATES: 20 2 2 2 47
# E0 = -4.2470163234
# E0 = -3.89436497869
# EXCITED OVERLAP(0) = 3.35897412218e-07
# E(1) = -3.89436497868
# GAP(1) = -4.2470163234 -3.89436497868 0.352651344715
# ITER = 7 ENTROPY = 0.686393446418
# -------------------------------------------
# Truncation error = 3.60822483003e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_8_liBq4iW
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_8_lK5Dcal
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_7_lXat3uQ
# WARMUP LEFT-TO-RIGHT ITERATION 8
# NUMBER OF STATES: 20 2 2 2 54
# E0 = -4.6243204984
# E0 = -4.18747321419
# EXCITED OVERLAP(0) = -1.60298913032e-09
# E(1) = -4.18747321419
# GAP(1) = -4.6243204984 -4.18747321419 0.436847284207
# ITER = 8 ENTROPY = 0.746858556871
# -------------------------------------------
# Truncation error = -1.38777878078e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_9_lsoPBg1
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_9_lUYiUhe
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_8_lYTZzdy
# WARMUP LEFT-TO-RIGHT ITERATION 9
# NUMBER OF STATES: 20 2 2 2 54
# E0 = -5.12555801778
# E0 = -4.80694703351
# EXCITED OVERLAP(0) = -5.05138098406e-07
# E(1) = -4.80694703351
# GAP(1) = -5.12555801778 -4.80694703351 0.318610984273
# ITER = 9 ENTROPY = 0.715492784647
# -------------------------------------------
# Truncation error = -2.98372437868e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_10_lKnubU0
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_10_lv8V1qC
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_9_lbVJYzx
# WARMUP LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -5.51401242128
# E0 = -5.11962924027
# EXCITED OVERLAP(0) = -4.10058098588e-12
# E(1) = -5.11962924029
# GAP(1) = -5.51401242128 -5.11962924029 0.394383180993
# ITER = 10 ENTROPY = 0.750973707809
# -------------------------------------------
# Truncation error = -1.38777878078e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_11_ljHWbfS
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_11_lGuzUwO
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_10_lAEHHx5
# WARMUP LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -6.00155559879
# E0 = -5.70464672398
# EXCITED OVERLAP(0) = -2.5384845892e-09
# E(1) = -5.70464672398
# GAP(1) = -6.00155559879 -5.70464672398 0.29690887481
# ITER = 11 ENTROPY = 0.728065210357
# -------------------------------------------
# Truncation error = 1.5959455979e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_12_lX49Oh1
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_12_lMhE8jy
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_11_lIEUmGd
# WARMUP LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -6.39844602577
# E0 = -6.03558054616
# EXCITED OVERLAP(0) = 3.33465337649e-07
# E(1) = -6.03558054616
# GAP(1) = -6.39844602577 -6.03558054616 0.362865479608
# ITER = 12 ENTROPY = 0.748758026908
# -------------------------------------------
# Truncation error = 1.80411241502e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_13_ljHnQBU
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_13_lo1LAyq
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_12_lh25HzP
# WARMUP LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 20 2 2 2 54
# E0 = -6.87527472283
# E0 = -6.58243184809
# EXCITED OVERLAP(0) = 9.94612170402e-11
# E(1) = -6.58243184809
# GAP(1) = -6.87527472283 -6.58243184809 0.29284287474
# ITER = 13 ENTROPY = 0.729647152581
# -------------------------------------------
# Truncation error = 1.35308431126e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_14_lGHhNzr
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_14_lzIAszw
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_13_lTR8gWV
# WARMUP LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -7.28167197852
# E0 = -6.93556011744
# EXCITED OVERLAP(0) = 1.17841122693e-08
# E(1) = -6.93556011745
# GAP(1) = -7.28167197852 -6.93556011745 0.346111861077
# ITER = 14 ENTROPY = 0.745005095075
# -------------------------------------------
# Truncation error = -1.31838984174e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_15_lromOwg
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_15_ll3zsSa
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_14_lFktOBw
# WARMUP LEFT-TO-RIGHT ITERATION 15
# NUMBER OF STATES: 20 2 2 2 54
# E0 = -7.74720366627
# E0 = -7.45264952286
# EXCITED OVERLAP(0) = -5.41844490387e-08
# E(1) = -7.45264952286
# GAP(1) = -7.74720366627 -7.45264952286 0.294554143405
# ITER = 15 ENTROPY = 0.73704233062
# -------------------------------------------
# Truncation error = 2.08166817117e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_16_lrfhizY
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_16_lK0S92S
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_15_ltrKIr5
# WARMUP LEFT-TO-RIGHT ITERATION 16
# NUMBER OF STATES: 20 2 2 2 48
# E0 = -8.16794586871
# E0 = -7.83673508307
# EXCITED OVERLAP(0) = 8.31584925171e-07
# E(1) = -7.83673508307
# GAP(1) = -8.16794586871 -7.83673508307 0.331210785638
# ITER = 16 ENTROPY = 0.749605518991
# -------------------------------------------
# Truncation error = 1.04083408559e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_17_lvHTkKA
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_17_ldPzrSI
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_16_l6WXXuV
# WARMUP LEFT-TO-RIGHT ITERATION 17
# NUMBER OF STATES: 20 2 2 2 54
# E0 = -8.62416355556
# E0 = -8.32349888919
# EXCITED OVERLAP(0) = 7.69106607817e-07
# E(1) = -8.32349888918
# GAP(1) = -8.62416355556 -8.32349888918 0.300664666379
# ITER = 17 ENTROPY = 0.741177884521
# -------------------------------------------
# Truncation error = 3.05311331772e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_18_lhBm65y
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_18_leoA5Cy
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_17_lMjSwnD
# WARMUP LEFT-TO-RIGHT ITERATION 18
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -9.0466800891
# E0 = -8.72542454653
# EXCITED OVERLAP(0) = 1.8904658039e-07
# E(1) = -8.72542454655
# GAP(1) = -9.0466800891 -8.72542454655 0.321255542558
# ITER = 18 ENTROPY = 0.74197368865
# -------------------------------------------
# Truncation error = 4.85722573274e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_19_lgr8XMK
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_19_lXSlDyf
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_18_lEvTr84
# WARMUP LEFT-TO-RIGHT ITERATION 19
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -9.49690853766
# E0 = -9.19600514014
# EXCITED OVERLAP(0) = -1.22864427736e-07
# E(1) = -9.19600514014
# GAP(1) = -9.49690853766 -9.19600514014 0.300903397523
# ITER = 19 ENTROPY = 0.738504647389
# -------------------------------------------
# Truncation error = 5.84601811404e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_20_l3Fmb1M
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_20_lDLg7U0
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_19_latzwvF
# WARMUP LEFT-TO-RIGHT ITERATION 20
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -9.92804925496
# E0 = -9.61308843557
# EXCITED OVERLAP(0) = 8.47536837933e-09
# E(1) = -9.61308843556
# GAP(1) = -9.92804925496 -9.61308843556 0.314960819398
# ITER = 20 ENTROPY = 0.741778514488
# -------------------------------------------
# Truncation error = 0
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_21_lon0NF3
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_21_lmRL1Tz
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_20_l3p1PBD
# WARMUP LEFT-TO-RIGHT ITERATION 21
# NUMBER OF STATES: 20 2 2 2 54
# E0 = -10.3805896791
# E0 = -9.83386443445
# EXCITED OVERLAP(0) = 1.01195112734e-07
# E(1) = -9.83386443444
# GAP(1) = -10.3805896791 -9.83386443444 0.546725244608
# ITER = 21 ENTROPY = 0.649837138901
# -------------------------------------------
# Truncation error = -3.81639164715e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_22_l885EMg
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_22_lDAEn4N
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_21_lFHrJhN
# WARMUP LEFT-TO-RIGHT ITERATION 22
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -10.8119516878
# E0 = -10.3381284159
# EXCITED OVERLAP(0) = -7.95325088301e-07
# E(1) = -10.3381284159
# GAP(1) = -10.8119516878 -10.3381284159 0.473823271944
# ITER = 22 ENTROPY = 0.728447233797
# -------------------------------------------
# Truncation error = 6.93889390391e-18
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_23_l12SzXf
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_23_lYSbXDF
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_22_lXzyu6h
# WARMUP LEFT-TO-RIGHT ITERATION 23
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -11.2644900622
# E0 = -10.7994647681
# EXCITED OVERLAP(0) = -6.61660448653e-11
# E(1) = -10.7994647681
# GAP(1) = -11.2644900622 -10.7994647681 0.465025294085
# ITER = 23 ENTROPY = 0.733665355915
# -------------------------------------------
# Truncation error = -8.32667268469e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_24_lx5efhU
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_24_lRiCACM
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_23_lAs0i1K
# WARMUP LEFT-TO-RIGHT ITERATION 24
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -11.6942016085
# E0 = -11.2456081502
# EXCITED OVERLAP(0) = 6.25429041889e-10
# E(1) = -11.2456081502
# GAP(1) = -11.6942016085 -11.2456081502 0.448593458255
# ITER = 24 ENTROPY = 0.731218066007
# -------------------------------------------
# Truncation error = -2.35922392733e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_25_lnEiakg
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_25_lpVexvS
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_24_l4bYq1g
# WARMUP LEFT-TO-RIGHT ITERATION 25
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -12.1400988536
# E0 = -11.6800638532
# EXCITED OVERLAP(0) = -1.03335443813e-08
# E(1) = -11.6800638532
# GAP(1) = -12.1400988536 -11.6800638532 0.460035000417
# ITER = 25 ENTROPY = 0.731083762809
# -------------------------------------------
# Truncation error = -2.46330733589e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_26_lNigbiw
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_26_lKubzmg
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_25_l4Eb8ON
# WARMUP LEFT-TO-RIGHT ITERATION 26
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -12.573239581
# E0 = -12.1326600292
# EXCITED OVERLAP(0) = -6.50221810714e-07
# E(1) = -12.1326600292
# GAP(1) = -12.573239581 -12.1326600292 0.440579551781
# ITER = 26 ENTROPY = 0.733036516865
# -------------------------------------------
# Truncation error = 3.12250225676e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_27_lv1nhxn
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_27_lSqLD45
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_26_lVobSqy
# WARMUP LEFT-TO-RIGHT ITERATION 27
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -13.0171192975
# E0 = -12.5705190011
# EXCITED OVERLAP(0) = 6.47256254149e-09
# E(1) = -12.5705190011
# GAP(1) = -13.0171192975 -12.5705190011 0.44660029648
# ITER = 27 ENTROPY = 0.73095469857
# -------------------------------------------
# Truncation error = 4.66640615038e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_28_lQ1jCaB
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_28_l8lDx5c
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_27_l0cQLS2
# WARMUP LEFT-TO-RIGHT ITERATION 28
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -13.4524189768
# E0 = -13.0137201605
# EXCITED OVERLAP(0) = -1.63994458624e-07
# E(1) = -13.0137201605
# GAP(1) = -13.4524189768 -13.0137201605 0.438698816234
# ITER = 28 ENTROPY = 0.726937255728
# -------------------------------------------
# Truncation error = 1.94289029309e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_29_lwJ5BAW
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_29_l4B3F6J
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_28_lBb9DZF
# RIGHT-TO-LEFT sweep to get B(1)B(2)...B(L/2-1)
# WARMUP RIGHT-TO-LEFT ITERATION 1
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -13.8942191123
# E0 = -13.4523448729
# EXCITED OVERLAP(0) = -1.13473196117e-09
# E(1) = -13.4523448729
# GAP(1) = -13.8942191123 -13.4523448729 0.441874239358
# ITER = 1 ENTROPY = 0.384491622522
# -------------------------------------------
# Truncation error = 2.01227923213e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_2_rcKh3yr
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_2_rf8tTYq
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_1_r41Q1Z2
# WARMUP RIGHT-TO-LEFT ITERATION 2
# NUMBER OF STATES: 20 2 2 4 98
# E0 = -13.904319755
# E0 = -13.486317157
# EXCITED OVERLAP(0) = 7.63429729156e-10
# E(1) = -13.486317157
# GAP(1) = -13.904319755 -13.486317157 0.418002597995
# ITER = 2 ENTROPY = 0.696229844036
# -------------------------------------------
# Truncation error = 3.77302356025e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_3_rdfGqCs
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_3_rT1qezN
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_2_rNWzhpr
# WARMUP RIGHT-TO-LEFT ITERATION 3
# NUMBER OF STATES: 20 2 2 8 175
# E0 = -13.9046380212
# E0 = -13.4884547448
# EXCITED OVERLAP(0) = 5.39524313004e-08
# E(1) = -13.4884547448
# GAP(1) = -13.9046380212 -13.4884547448 0.416183276449
# ITER = 3 ENTROPY = 0.576729951141
# -------------------------------------------
# Truncation error = -1.18269516359e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_4_rs7Zfud
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_4_rBVRKJN
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_3_rKY4WYC
# WARMUP RIGHT-TO-LEFT ITERATION 4
# NUMBER OF STATES: 20 2 2 16 345
# E0 = -13.9134892587
# E0 = -13.5411212308
# EXCITED OVERLAP(0) = -1.96980627643e-09
# E(1) = -13.5411212309
# GAP(1) = -13.9134892587 -13.5411212309 0.372368027809
# ITER = 4 ENTROPY = 0.798513375521
# -------------------------------------------
# Truncation error = 1.59778011117e-08
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_5_rYphQJT
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_5_rUZ6RRP
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_4_rYyWVYD
# WARMUP RIGHT-TO-LEFT ITERATION 5
# NUMBER OF STATES: 20 2 2 20 460
# E0 = -13.9142150793
# E0 = -13.5493480243
# EXCITED OVERLAP(0) = -9.80797999414e-09
# E(1) = -13.5493480243
# GAP(1) = -13.9142150793 -13.5493480243 0.364867055006
# ITER = 5 ENTROPY = 0.729156447508
# -------------------------------------------
# Truncation error = 1.25617760944e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_6_rv6QAcX
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_6_rFBGGUj
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_5_rfs8LmT
# WARMUP RIGHT-TO-LEFT ITERATION 6
# NUMBER OF STATES: 20 2 2 20 486
# E0 = -13.9235412901
# E0 = -13.6171003819
# EXCITED OVERLAP(0) = -2.28677979164e-07
# E(1) = -13.6171003819
# GAP(1) = -13.9235412901 -13.6171003819 0.306440908225
# ITER = 6 ENTROPY = 0.866318189066
# -------------------------------------------
# Truncation error = 4.56861429361e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_7_rSjepZb
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_7_rQI7Iuj
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_6_rqX7sp3
# WARMUP RIGHT-TO-LEFT ITERATION 7
# NUMBER OF STATES: 20 2 2 20 460
# E0 = -13.9242577721
# E0 = -13.6270386738
# EXCITED OVERLAP(0) = -5.03010515087e-07
# E(1) = -13.6270386738
# GAP(1) = -13.9242577721 -13.6270386738 0.297219098264
# ITER = 7 ENTROPY = 0.797082336584
# -------------------------------------------
# Truncation error = 6.87422994553e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_8_rTBY534
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_8_rhLyK5p
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_7_r06z38z
# WARMUP RIGHT-TO-LEFT ITERATION 8
# NUMBER OF STATES: 20 2 2 20 472
# E0 = -13.9266490785
# E0 = -13.6477698897
# EXCITED OVERLAP(0) = -4.90568847003e-09
# E(1) = -13.6477698897
# GAP(1) = -13.9266490785 -13.6477698897 0.278879188791
# ITER = 8 ENTROPY = 0.910407802922
# -------------------------------------------
# Truncation error = 1.15159270926e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_9_r0JSFNq
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_9_r6o2Em2
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_8_rCrRBWF
# WARMUP RIGHT-TO-LEFT ITERATION 9
# NUMBER OF STATES: 20 2 2 20 470
# E0 = -13.9273754797
# E0 = -13.6610739631
# EXCITED OVERLAP(0) = 1.41417558053e-07
# E(1) = -13.6610739631
# GAP(1) = -13.9273754797 -13.6610739631 0.266301516605
# ITER = 9 ENTROPY = 0.790737008848
# -------------------------------------------
# Truncation error = 1.834821742e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_10_rWwkS8k
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_10_r9SaZbS
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_9_r9eeiXc
# WARMUP RIGHT-TO-LEFT ITERATION 10
# NUMBER OF STATES: 20 2 2 20 475
# E0 = -13.9295463039
# E0 = -13.6736929439
# EXCITED OVERLAP(0) = -5.1440351978e-11
# E(1) = -13.6736929439
# GAP(1) = -13.9295463039 -13.6736929439 0.25585336
# ITER = 10 ENTROPY = 0.888117047938
# -------------------------------------------
# Truncation error = 1.17717929498e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_11_rK95GVN
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_11_r5LKHIB
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_10_rwLI4d8
# WARMUP RIGHT-TO-LEFT ITERATION 11
# NUMBER OF STATES: 20 2 2 20 458
# E0 = -13.9309122231
# E0 = -13.6775031397
# EXCITED OVERLAP(0) = 4.65455617965e-07
# E(1) = -13.6775031397
# GAP(1) = -13.9309122231 -13.6775031397 0.253409083425
# ITER = 11 ENTROPY = 0.827854181204
# -------------------------------------------
# Truncation error = 9.24862309521e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_12_rNxtaBP
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_12_rKmiTCA
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_11_rmBSBzy
# WARMUP RIGHT-TO-LEFT ITERATION 12
# NUMBER OF STATES: 20 2 2 20 472
# E0 = -13.9402985624
# E0 = -13.6227959375
# EXCITED OVERLAP(0) = 1.72935187358e-07
# E(1) = -13.6227959375
# GAP(1) = -13.9402985624 -13.6227959375 0.317502624954
# ITER = 12 ENTROPY = 0.787030008558
# -------------------------------------------
# Truncation error = 1.39761380183e-06
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_13_rGTvruf
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_13_rNlAxrY
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_12_rOFdy5B
# WARMUP RIGHT-TO-LEFT ITERATION 13
# NUMBER OF STATES: 20 2 2 20 478
# E0 = -13.9421983262
# E0 = -13.7266252106
# EXCITED OVERLAP(0) = 9.7663484331e-10
# E(1) = -13.7266252106
# GAP(1) = -13.9421983262 -13.7266252106 0.215573115649
# ITER = 13 ENTROPY = 0.848354065845
# -------------------------------------------
# Truncation error = 2.13771482031e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_14_ruWzmZY
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_14_rDW8x9n
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_13_r5Y63Qq
# WARMUP RIGHT-TO-LEFT ITERATION 14
# NUMBER OF STATES: 20 2 2 20 464
# E0 = -13.9484338544
# E0 = -13.7534075606
# EXCITED OVERLAP(0) = -9.08023230495e-08
# E(1) = -13.7534075606
# GAP(1) = -13.9484338544 -13.7534075606 0.195026293834
# ITER = 14 ENTROPY = 0.965506955537
# -------------------------------------------
# Truncation error = 1.34313806212e-06
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_15_ritcwjG
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_15_rLDtbjB
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_14_rdR4wDA
# WARMUP RIGHT-TO-LEFT ITERATION 15
# NUMBER OF STATES: 20 2 2 20 468
# E0 = -13.9492003996
# E0 = -13.7563719173
# EXCITED OVERLAP(0) = -3.12329653807e-09
# E(1) = -13.7563719173
# GAP(1) = -13.9492003996 -13.7563719173 0.192828482288
# ITER = 15 ENTROPY = 0.860027876584
# -------------------------------------------
# Truncation error = 5.82550235931e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_16_re3bsis
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_16_rWA4bi7
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_15_rs9WUqs
# WARMUP RIGHT-TO-LEFT ITERATION 16
# NUMBER OF STATES: 20 2 2 20 480
# E0 = -13.9585211353
# E0 = -13.7888086334
# EXCITED OVERLAP(0) = -9.51060536505e-08
# E(1) = -13.7888086334
# GAP(1) = -13.9585211353 -13.7888086334 0.16971250194
# ITER = 16 ENTROPY = 0.976598190427
# -------------------------------------------
# Truncation error = 7.47739772491e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_17_rgNh7TR
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_17_rIfgFr9
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_16_rTJADHQ
# WARMUP RIGHT-TO-LEFT ITERATION 17
# NUMBER OF STATES: 20 2 2 20 478
# E0 = -13.9598929319
# E0 = -13.7923666244
# EXCITED OVERLAP(0) = -1.26932996995e-08
# E(1) = -13.7923666244
# GAP(1) = -13.9598929319 -13.7923666244 0.167526307496
# ITER = 17 ENTROPY = 0.869778881511
# -------------------------------------------
# Truncation error = 4.65740281809e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_18_r22hLbL
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_18_r2ZCm3l
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_17_rpDtYPo
# WARMUP RIGHT-TO-LEFT ITERATION 18
# NUMBER OF STATES: 20 2 2 20 486
# E0 = -13.9692063561
# E0 = -13.8214772294
# EXCITED OVERLAP(0) = 1.67353019637e-08
# E(1) = -13.8214772294
# GAP(1) = -13.9692063561 -13.8214772294 0.147729126745
# ITER = 18 ENTROPY = 1.00320270287
# -------------------------------------------
# Truncation error = 9.10380660968e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_19_rRV7Tmy
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_19_rbDrHqA
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_18_rZxCTiN
# WARMUP RIGHT-TO-LEFT ITERATION 19
# NUMBER OF STATES: 20 2 2 20 450
# E0 = -13.9704293007
# E0 = -13.8249291059
# EXCITED OVERLAP(0) = 9.02117233414e-08
# E(1) = -13.8249291059
# GAP(1) = -13.9704293007 -13.8249291059 0.145500194783
# ITER = 19 ENTROPY = 0.899603400956
# -------------------------------------------
# Truncation error = 1.14034489223e-06
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_20_rFMejqb
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_20_rI9nVMD
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_19_r7wafSP
# WARMUP RIGHT-TO-LEFT ITERATION 20
# NUMBER OF STATES: 20 2 2 20 474
# E0 = -13.9772466687
# E0 = -13.8398786936
# EXCITED OVERLAP(0) = 6.01447090048e-10
# E(1) = -13.8398786936
# GAP(1) = -13.9772466687 -13.8398786936 0.137367975131
# ITER = 20 ENTROPY = 1.02913697678
# -------------------------------------------
# Truncation error = 9.12488697271e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_21_rP9G2DB
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_21_rahVPTV
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_20_rpDNYbd
# WARMUP RIGHT-TO-LEFT ITERATION 21
# NUMBER OF STATES: 20 2 2 20 472
# E0 = -13.9778553796
# E0 = -13.8409511548
# EXCITED OVERLAP(0) = 2.67280450383e-07
# E(1) = -13.8409511547
# GAP(1) = -13.9778553796 -13.8409511547 0.136904224899
# ITER = 21 ENTROPY = 0.898070317432
# -------------------------------------------
# Truncation error = 2.31784111627e-06
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_22_rtycWFT
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_22_rNbuhQ9
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_21_rxjdtcg
# WARMUP RIGHT-TO-LEFT ITERATION 22
# NUMBER OF STATES: 20 2 2 20 485
# E0 = -13.981845334
# E0 = -13.8497587994
# EXCITED OVERLAP(0) = 8.72494035353e-09
# E(1) = -13.8497587994
# GAP(1) = -13.981845334 -13.8497587994 0.132086534518
# ITER = 22 ENTROPY = 1.04687231415
# -------------------------------------------
# Truncation error = 6.82478371901e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_23_rzzyUCS
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_23_ra2X2lQ
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_22_rLBNYfw
# WARMUP RIGHT-TO-LEFT ITERATION 23
# NUMBER OF STATES: 20 2 2 20 424
# E0 = -13.9824562008
# E0 = -13.8504619015
# EXCITED OVERLAP(0) = -7.59223569326e-07
# E(1) = -13.8504619015
# GAP(1) = -13.9824562008 -13.8504619015 0.131994299276
# ITER = 23 ENTROPY = 0.903153095146
# -------------------------------------------
# Truncation error = 2.50668902491e-06
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_24_r4yJCBG
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_24_rjeNMMM
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_23_rz24jwm
# WARMUP RIGHT-TO-LEFT ITERATION 24
# NUMBER OF STATES: 20 2 2 20 433
# E0 = -13.9896499384
# E0 = -13.8636274417
# EXCITED OVERLAP(0) = -3.75140029051e-07
# E(1) = -13.8636274417
# GAP(1) = -13.9896499384 -13.8636274417 0.126022496693
# ITER = 24 ENTROPY = 1.06641115961
# -------------------------------------------
# Truncation error = 6.53551254077e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_25_rww4sbY
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_25_rVWPrxw
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_24_rIHFcov
# WARMUP RIGHT-TO-LEFT ITERATION 25
# NUMBER OF STATES: 20 2 2 20 393
# E0 = -13.9899069177
# E0 = -13.8643532299
# EXCITED OVERLAP(0) = -2.12804189548e-09
# E(1) = -13.8643532299
# GAP(1) = -13.9899069177 -13.8643532299 0.125553687859
# ITER = 25 ENTROPY = 0.894619800789
# -------------------------------------------
# Truncation error = 7.17867805569e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_26_raYKKA3
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_26_r1SraYi
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_25_rOTdLAr
# WARMUP RIGHT-TO-LEFT ITERATION 26
# NUMBER OF STATES: 16 2 2 20 336
# E0 = -13.9963132739
# E0 = -13.8742505526
# EXCITED OVERLAP(0) = -7.43095927153e-09
# E(1) = -13.8742505526
# GAP(1) = -13.9963132739 -13.8742505526 0.122062721262
# ITER = 26 ENTROPY = 1.08000624139
# -------------------------------------------
# Truncation error = 6.33875303181e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_27_ro1p9Vx
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_27_roChaVy
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_26_rphEYMo
# WARMUP RIGHT-TO-LEFT ITERATION 27
# NUMBER OF STATES: 8 2 2 20 175
# E0 = -13.9963120651
# E0 = -13.8742462072
# EXCITED OVERLAP(0) = -3.59834202365e-09
# E(1) = -13.8742462072
# GAP(1) = -13.9963120651 -13.8742462072 0.122065857876
# ITER = 27 ENTROPY = 0.883749114078
# -------------------------------------------
# Truncation error = 8.16924712829e-07
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_28_rKY5emq
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_28_rPF6MVj
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_27_rgQqzlS
# WARMUP RIGHT-TO-LEFT ITERATION 28
# NUMBER OF STATES: 4 2 2 20 95
# E0 = -13.9963100079
# E0 = -13.8735374564
# EXCITED OVERLAP(0) = 1.3097268492e-07
# E(1) = -13.8735374564
# GAP(1) = -13.9963100079 -13.8735374564 0.122772551466
# ITER = 28 ENTROPY = 1.07628290774
# -------------------------------------------
# Truncation error = -1.62576115764e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_29_rkoFytb
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_29_rptnOU4
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_28_rorFtxd
# WARMUP LEFT-TO-RIGHT ITERATION 1
# NUMBER OF STATES: 2 2 2 20 52
# E0 = -13.9963100123
# E0 = -13.8740526158
# EXCITED OVERLAP(0) = -8.65954230711e-07
# E(1) = -13.8740526158
# GAP(1) = -13.9963100123 -13.8740526158 0.122257396515
# ITER = 1 ENTROPY = 0.432008937186
# -------------------------------------------
# Truncation error = 2.49800180541e-16
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 2
# NUMBER OF STATES: 4 2 2 20 95
# E0 = -13.996310016
# E0 = -13.874225554
# EXCITED OVERLAP(0) = -6.82265904467e-08
# E(1) = -13.874225554
# GAP(1) = -13.996310016 -13.874225554 0.122084461937
# ITER = 2 ENTROPY = 0.739206354122
# -------------------------------------------
# Truncation error = -1.2332799712e-16
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 3
# NUMBER OF STATES: 8 2 2 20 175
# E0 = -13.9963120817
# E0 = -13.8742438484
# EXCITED OVERLAP(0) = 1.14757003303e-07
# E(1) = -13.8742438484
# GAP(1) = -13.9963120817 -13.8742438484 0.122068233263
# ITER = 3 ENTROPY = 0.564073911228
# -------------------------------------------
# Truncation error = -6.13608137046e-17
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 4
# NUMBER OF STATES: 16 2 2 20 336
# E0 = -13.9963133034
# E0 = -13.8742521362
# EXCITED OVERLAP(0) = -2.36583506258e-09
# E(1) = -13.8742521362
# GAP(1) = -13.9963133034 -13.8742521362 0.122061167217
# ITER = 4 ENTROPY = 0.779863905621
# -------------------------------------------
# Truncation error = 3.76560730514e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 5
# NUMBER OF STATES: 20 2 2 20 440
# E0 = -13.9963388533
# E0 = -13.8743307952
# EXCITED OVERLAP(0) = -1.23346127756e-09
# E(1) = -13.8743307952
# GAP(1) = -13.9963388533 -13.8743307952 0.122008058122
# ITER = 5 ENTROPY = 0.644696056556
# -------------------------------------------
# Truncation error = 2.02377462755e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 6
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.996350027
# E0 = -13.8744073209
# EXCITED OVERLAP(0) = 1.02229458177e-07
# E(1) = -13.8744073209
# GAP(1) = -13.996350027 -13.8744073209 0.121942706107
# ITER = 6 ENTROPY = 0.816560424453
# -------------------------------------------
# Truncation error = 5.09471109904e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 7
# NUMBER OF STATES: 20 2 2 20 440
# E0 = -13.9964441234
# E0 = -13.8747882188
# EXCITED OVERLAP(0) = 1.00789226964e-09
# E(1) = -13.8747882188
# GAP(1) = -13.9964441234 -13.8747882188 0.121655904659
# ITER = 7 ENTROPY = 0.708307655638
# -------------------------------------------
# Truncation error = 1.13628673541e-07
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 8
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.9964730952
# E0 = -13.8749557519
# EXCITED OVERLAP(0) = -8.59497999994e-08
# E(1) = -13.8749557519
# GAP(1) = -13.9964730952 -13.8749557519 0.121517343266
# ITER = 8 ENTROPY = 0.853087570223
# -------------------------------------------
# Truncation error = 2.46198764828e-07
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 9
# NUMBER OF STATES: 20 2 2 20 440
# E0 = -13.9965052742
# E0 = -13.8751083989
# EXCITED OVERLAP(0) = -9.70365565678e-10
# E(1) = -13.8751083989
# GAP(1) = -13.9965052742 -13.8751083989 0.12139687524
# ITER = 9 ENTROPY = 0.760210554049
# -------------------------------------------
# Truncation error = 3.41335664718e-07
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.996531354
# E0 = -13.8752758462
# EXCITED OVERLAP(0) = -1.14870522289e-07
# E(1) = -13.8752758462
# GAP(1) = -13.996531354 -13.8752758462 0.121255507808
# ITER = 10 ENTROPY = 0.887054136527
# -------------------------------------------
# Truncation error = 6.20690610677e-07
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 20 2 2 20 450
# E0 = -13.9965649719
# E0 = -13.8754361811
# EXCITED OVERLAP(0) = 8.95864687989e-10
# E(1) = -13.8754361811
# GAP(1) = -13.9965649719 -13.8754361811 0.121128790798
# ITER = 11 ENTROPY = 0.805201351953
# -------------------------------------------
# Truncation error = 7.15830609525e-07
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.9965875843
# E0 = -13.8755700589
# EXCITED OVERLAP(0) = -6.26635757173e-10
# E(1) = -13.8755700589
# GAP(1) = -13.9965875843 -13.8755700589 0.121017525439
# ITER = 12 ENTROPY = 0.919720453874
# -------------------------------------------
# Truncation error = 1.10309292181e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 20 2 2 20 450
# E0 = -13.9967237277
# E0 = -13.876204649
# EXCITED OVERLAP(0) = -8.30838303441e-07
# E(1) = -13.876204649
# GAP(1) = -13.9967237277 -13.876204649 0.120519078663
# ITER = 13 ENTROPY = 0.846342750199
# -------------------------------------------
# Truncation error = 1.28515110135e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.996774991
# E0 = -13.8765312071
# EXCITED OVERLAP(0) = 1.29517178926e-09
# E(1) = -13.8765312071
# GAP(1) = -13.996774991 -13.8765312071 0.120243783895
# ITER = 14 ENTROPY = 0.954539455723
# -------------------------------------------
# Truncation error = 1.92828981077e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 15
# NUMBER OF STATES: 20 2 2 20 440
# E0 = -13.9968180051
# E0 = -13.8767515216
# EXCITED OVERLAP(0) = -1.04061387285e-09
# E(1) = -13.8767515216
# GAP(1) = -13.9968180051 -13.8767515216 0.120066483491
# ITER = 15 ENTROPY = 0.88112883656
# -------------------------------------------
# Truncation error = 2.03168339943e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 16
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.9968715936
# E0 = -13.8770566064
# EXCITED OVERLAP(0) = -1.01058424129e-09
# E(1) = -13.8770566064
# GAP(1) = -13.9968715936 -13.8770566064 0.119814987194
# ITER = 16 ENTROPY = 0.985117654275
# -------------------------------------------
# Truncation error = 2.51918018454e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 17
# NUMBER OF STATES: 20 2 2 20 450
# E0 = -13.99696896
# E0 = -13.8774982281
# EXCITED OVERLAP(0) = 1.29066421439e-09
# E(1) = -13.8774982281
# GAP(1) = -13.99696896 -13.8774982281 0.119470731959
# ITER = 17 ENTROPY = 0.910385130584
# -------------------------------------------
# Truncation error = 2.69631909167e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 18
# NUMBER OF STATES: 20 2 2 20 424
# E0 = -13.9970856573
# E0 = -13.8782509598
# EXCITED OVERLAP(0) = -1.21395328512e-09
# E(1) = -13.8782509598
# GAP(1) = -13.9970856573 -13.8782509598 0.118834697481
# ITER = 18 ENTROPY = 1.01589335269
# -------------------------------------------
# Truncation error = 3.33403629562e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 19
# NUMBER OF STATES: 20 2 2 20 440
# E0 = -13.9971731451
# E0 = -13.8787969798
# EXCITED OVERLAP(0) = 1.10170111922e-09
# E(1) = -13.8787969798
# GAP(1) = -13.9971731451 -13.8787969798 0.118376165231
# ITER = 19 ENTROPY = 0.934310018878
# -------------------------------------------
# Truncation error = 3.56405556448e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 20
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.9971875002
# E0 = -13.878892866
# EXCITED OVERLAP(0) = -1.30907534812e-09
# E(1) = -13.878892866
# GAP(1) = -13.9971875002 -13.878892866 0.118294634256
# ITER = 20 ENTROPY = 1.04120354432
# -------------------------------------------
# Truncation error = 3.76778393031e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 21
# NUMBER OF STATES: 20 2 2 20 440
# E0 = -13.9972155252
# E0 = -13.8790134338
# EXCITED OVERLAP(0) = 2.92382562606e-10
# E(1) = -13.8790134338
# GAP(1) = -13.9972155252 -13.8790134338 0.118202091335
# ITER = 21 ENTROPY = 0.94598108835
# -------------------------------------------
# Truncation error = 3.77941737542e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 22
# NUMBER OF STATES: 20 2 2 20 424
# E0 = -13.9972155789
# E0 = -13.879023307
# EXCITED OVERLAP(0) = -2.43160637459e-09
# E(1) = -13.879023307
# GAP(1) = -13.9972155789 -13.879023307 0.118192271886
# ITER = 22 ENTROPY = 1.06165074234
# -------------------------------------------
# Truncation error = 3.37953025585e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 23
# NUMBER OF STATES: 20 2 2 20 440
# E0 = -13.9972309693
# E0 = -13.8790830903
# EXCITED OVERLAP(0) = 4.08332201385e-10
# E(1) = -13.8790830903
# GAP(1) = -13.9972309693 -13.8790830903 0.118147878908
# ITER = 23 ENTROPY = 0.945955854394
# -------------------------------------------
# Truncation error = 3.43483896093e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 24
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.9972279734
# E0 = -13.8790687566
# EXCITED OVERLAP(0) = -9.69799379691e-10
# E(1) = -13.8790687566
# GAP(1) = -13.9972279734 -13.8790687566 0.118159216801
# ITER = 24 ENTROPY = 1.07579971782
# -------------------------------------------
# Truncation error = 2.23116265983e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 25
# NUMBER OF STATES: 20 2 2 20 440
# E0 = -13.9972363773
# E0 = -13.8790894577
# EXCITED OVERLAP(0) = -6.21882645352e-07
# E(1) = -13.8790894577
# GAP(1) = -13.9972363773 -13.8790894577 0.118146919658
# ITER = 25 ENTROPY = 0.929962276126
# -------------------------------------------
# Truncation error = 2.40086068029e-06
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 26
# NUMBER OF STATES: 20 2 2 16 322
# E0 = -13.9972331835
# E0 = -13.8790744791
# EXCITED OVERLAP(0) = -4.60947896241e-07
# E(1) = -13.8790744791
# GAP(1) = -13.9972331835 -13.8790744791 0.118158704409
# ITER = 26 ENTROPY = 1.08164102984
# -------------------------------------------
# Truncation error = 8.96393410593e-07
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 27
# NUMBER OF STATES: 20 2 2 8 175
# E0 = -13.9972315957
# E0 = -13.8790668525
# EXCITED OVERLAP(0) = -4.04790430342e-07
# E(1) = -13.8790668525
# GAP(1) = -13.9972315957 -13.8790668525 0.118164743283
# ITER = 27 ENTROPY = 0.886785973866
# -------------------------------------------
# Truncation error = 9.05510284741e-07
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 28
# NUMBER OF STATES: 20 2 2 4 95
# E0 = -13.9972293343
# E0 = -13.8790566225
# ...
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = -4.82324455347e-17
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794978
# ITER = 4 ENTROPY = 0.783307920249
# -------------------------------------------
# Truncation error = -6.56495466547e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 5
# NUMBER OF STATES: 100 2 2 32 2912
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = 2.07895766574e-17
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794978
# ITER = 5 ENTROPY = 0.653130427379
# -------------------------------------------
# Truncation error = 7.574855936e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 6
# NUMBER OF STATES: 100 2 2 64 5712
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = 3.14331893847e-15
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794977
# ITER = 6 ENTROPY = 0.822288743171
# -------------------------------------------
# Truncation error = -6.08541369331e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 7
# NUMBER OF STATES: 100 2 2 100 8908
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = -2.98094882112e-14
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794966
# ITER = 7 ENTROPY = 0.7170737583
# -------------------------------------------
# Truncation error = 1.27085312094e-15
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 8
# NUMBER OF STATES: 100 2 2 100 9221
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = 3.72687991579e-14
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794956
# ITER = 8 ENTROPY = 0.858799384429
# -------------------------------------------
# Truncation error = 1.13421558122e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 9
# NUMBER OF STATES: 100 2 2 100 9180
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = -9.99630337273e-14
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794922
# ITER = 9 ENTROPY = 0.770039899714
# -------------------------------------------
# Truncation error = 9.1189593708e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 10
# NUMBER OF STATES: 100 2 2 100 9250
# E0 = -13.9973156182
# E0 = -13.8795758233
# EXCITED OVERLAP(0) = 8.62972887594e-14
# E(1) = -13.8795758233
# GAP(1) = -13.9973156182 -13.8795758233 0.117739794896
# ITER = 10 ENTROPY = 0.893900732094
# -------------------------------------------
# Truncation error = 1.51661230526e-13
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 11
# NUMBER OF STATES: 100 2 2 100 9180
# E0 = -13.9973156182
# E0 = -13.8795758233
# EXCITED OVERLAP(0) = -1.62287230095e-13
# E(1) = -13.8795758233
# GAP(1) = -13.9973156182 -13.8795758233 0.117739794836
# ITER = 11 ENTROPY = 0.815967400353
# -------------------------------------------
# Truncation error = 6.2977409039e-13
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 12
# NUMBER OF STATES: 100 2 2 100 9250
# E0 = -13.9973156182
# E0 = -13.8795758234
# EXCITED OVERLAP(0) = 1.00367630873e-13
# E(1) = -13.8795758234
# GAP(1) = -13.9973156182 -13.8795758234 0.117739794806
# ITER = 12 ENTROPY = 0.927877263868
# -------------------------------------------
# Truncation error = 6.68858764264e-13
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 13
# NUMBER OF STATES: 100 2 2 100 9180
# E0 = -13.9973156182
# E0 = -13.8795758234
# EXCITED OVERLAP(0) = -1.59640421542e-13
# E(1) = -13.8795758234
# GAP(1) = -13.9973156182 -13.8795758234 0.117739794753
# ITER = 13 ENTROPY = 0.855792220199
# -------------------------------------------
# Truncation error = 2.02974652788e-12
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 14
# NUMBER OF STATES: 100 2 2 100 9451
# E0 = -13.9973156182
# E0 = -13.8795758235
# EXCITED OVERLAP(0) = 1.57490340214e-13
# E(1) = -13.8795758235
# GAP(1) = -13.9973156182 -13.8795758235 0.117739794743
# ITER = 14 ENTROPY = 0.960365695046
# -------------------------------------------
# Truncation error = 1.71085556977e-12
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 15
# NUMBER OF STATES: 100 2 2 100 9180
# E0 = -13.9973156182
# E0 = -13.8795758235
# EXCITED OVERLAP(0) = -1.49538042539e-13
# E(1) = -13.8795758235
# GAP(1) = -13.9973156182 -13.8795758235 0.117739794711
# ITER = 15 ENTROPY = 0.889751615063
# -------------------------------------------
# Truncation error = 3.8299744642e-12
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 16
# NUMBER OF STATES: 100 2 2 100 9451
# E0 = -13.9973156182
# E0 = -13.8795758235
# EXCITED OVERLAP(0) = 7.23275606074e-14
# E(1) = -13.8795758235
# GAP(1) = -13.9973156182 -13.8795758235 0.117739794737
# ITER = 16 ENTROPY = 0.991029650544
# -------------------------------------------
# Truncation error = 2.9105664256e-12
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 17
# NUMBER OF STATES: 100 2 2 100 9180
# E0 = -13.9973156182
# E0 = -13.8795758235
# EXCITED OVERLAP(0) = -1.13545295128e-13
# E(1) = -13.8795758235
# GAP(1) = -13.9973156182 -13.8795758235 0.117739794742
# ITER = 17 ENTROPY = 0.917259864682
# -------------------------------------------
# Truncation error = 4.95787119465e-12
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 18
# NUMBER OF STATES: 100 2 2 100 9250
# E0 = -13.9973156182
# E0 = -13.8795758234
# EXCITED OVERLAP(0) = 4.08874323288e-14
# E(1) = -13.8795758234
# GAP(1) = -13.9973156182 -13.8795758234 0.117739794793
# ITER = 18 ENTROPY = 1.01914687832
# -------------------------------------------
# Truncation error = 3.34368926503e-12
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 19
# NUMBER OF STATES: 100 2 2 100 9180
# E0 = -13.9973156182
# E0 = -13.8795758234
# EXCITED OVERLAP(0) = -3.47703094615e-14
# E(1) = -13.8795758234
# GAP(1) = -13.9973156182 -13.8795758234 0.11773979482
# ITER = 19 ENTROPY = 0.937429193924
# -------------------------------------------
# Truncation error = 4.40852710172e-12
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 20
# NUMBER OF STATES: 100 2 2 100 9250
# E0 = -13.9973156182
# E0 = -13.8795758233
# EXCITED OVERLAP(0) = 2.0762905284e-14
# E(1) = -13.8795758233
# GAP(1) = -13.9973156182 -13.8795758233 0.117739794879
# ITER = 20 ENTROPY = 1.04377664579
# -------------------------------------------
# Truncation error = 2.47333539469e-12
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 21
# NUMBER OF STATES: 100 2 2 100 9180
# E0 = -13.9973156182
# E0 = -13.8795758233
# EXCITED OVERLAP(0) = -1.1213875965e-14
# E(1) = -13.8795758233
# GAP(1) = -13.9973156182 -13.8795758233 0.117739794904
# ITER = 21 ENTROPY = 0.94865103097
# -------------------------------------------
# Truncation error = 2.59959337771e-12
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 22
# NUMBER OF STATES: 100 2 2 100 9250
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = 6.85389245358e-15
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794939
# ITER = 22 ENTROPY = 1.06371976037
# -------------------------------------------
# Truncation error = 9.64481932967e-13
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 23
# NUMBER OF STATES: 100 2 2 100 8816
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = -2.56880020727e-15
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794949
# ITER = 23 ENTROPY = 0.948121675008
# -------------------------------------------
# Truncation error = 7.83541599624e-13
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 24
# NUMBER OF STATES: 64 2 2 100 5712
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = 1.1483869411e-15
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.11773979496
# ITER = 24 ENTROPY = 1.07739215733
# -------------------------------------------
# Truncation error = 9.72358107665e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 25
# NUMBER OF STATES: 32 2 2 100 2912
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = -4.62873012488e-16
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794961
# ITER = 25 ENTROPY = 0.93150923848
# -------------------------------------------
# Truncation error = 4.60039584057e-15
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 26
# NUMBER OF STATES: 16 2 2 100 1498
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = 1.96588202017e-16
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794962
# ITER = 26 ENTROPY = 1.08257927581
# -------------------------------------------
# Truncation error = -1.1620199765e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 27
# NUMBER OF STATES: 8 2 2 100 809
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = -1.07552855511e-16
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794962
# ITER = 27 ENTROPY = 0.887698376703
# -------------------------------------------
# Truncation error = 2.53189318181e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 28
# NUMBER OF STATES: 4 2 2 100 420
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = -1.21430643318e-17
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794962
# ITER = 28 ENTROPY = 1.0761712419
# -------------------------------------------
# Truncation error = 1.90982212683e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 1
# NUMBER OF STATES: 2 2 2 100 236
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = -6.43880565185e-17
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794962
# ITER = 1 ENTROPY = 0.434136396164
# -------------------------------------------
# Truncation error = -4.16333634234e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 2
# NUMBER OF STATES: 4 2 2 100 420
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = -1.73472347598e-17
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794962
# ITER = 2 ENTROPY = 0.740364650314
# -------------------------------------------
# Truncation error = 1.97324795392e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 3
# NUMBER OF STATES: 8 2 2 100 809
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = 2.77555756156e-17
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794962
# ITER = 3 ENTROPY = 0.56899115605
# -------------------------------------------
# Truncation error = -4.002972359e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 4
# NUMBER OF STATES: 16 2 2 100 1498
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = 3.06837118524e-17
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794962
# ITER = 4 ENTROPY = 0.783307932664
# -------------------------------------------
# Truncation error = 1.31146631494e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 5
# NUMBER OF STATES: 32 2 2 100 2912
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = -7.45063732932e-16
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.117739794961
# ITER = 5 ENTROPY = 0.653130457278
# -------------------------------------------
# Truncation error = 1.13014054798e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 6
# NUMBER OF STATES: 64 2 2 100 5712
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = 1.34718625144e-14
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.11773979496
# ITER = 6 ENTROPY = 0.822288765366
# -------------------------------------------
# Truncation error = -2.71515863804e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 7
# NUMBER OF STATES: 100 2 2 100 8908
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = -1.20918683053e-13
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.11773979495
# ITER = 7 ENTROPY = 0.717073797939
# -------------------------------------------
# Truncation error = -1.06974170507e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 8
# NUMBER OF STATES: 100 2 2 100 9221
# E0 = -13.9973156182
# E0 = -13.8795758232
# EXCITED OVERLAP(0) = 6.95971058562e-14
# E(1) = -13.8795758232
# GAP(1) = -13.9973156182 -13.8795758232 0.11773979494
# ITER = 8 ENTROPY = 0.858799415881
# -------------------------------------------
# Truncation error = 1.20508652476e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 9
# NUMBER OF STATES: 100 2 2 100 9180
# E0 = -13.9973156182
# E0 = -13.8795758233
# EXCITED OVERLAP(0) = -2.51789637317e-13
# E(1) = -13.8795758233
# GAP(1) = -13.9973156182 -13.8795758233 0.117739794906
# ITER = 9 ENTROPY = 0.770039946223
# -------------------------------------------
# Truncation error = 9.26729512233e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 100 2 2 100 9250
# E0 = -13.9973156182
# E0 = -13.8795758233
# EXCITED OVERLAP(0) = 1.09882589139e-13
# E(1) = -13.8795758233
# GAP(1) = -13.9973156182 -13.8795758233 0.117739794881
# ITER = 10 ENTROPY = 0.89390077165
# -------------------------------------------
# Truncation error = 1.52197831118e-13
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 100 2 2 100 9180
# E0 = -13.9973156182
# E0 = -13.8795758234
# EXCITED OVERLAP(0) = -3.60532838393e-13
# E(1) = -13.8795758234
# GAP(1) = -13.9973156182 -13.8795758234 0.117739794822
# ITER = 11 ENTROPY = 0.815967450811
# -------------------------------------------
# Truncation error = 6.31154053402e-13
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 100 2 2 100 9250
# E0 = -13.9973156182
# E0 = -13.8795758234
# EXCITED OVERLAP(0) = 1.1302243863e-13
# E(1) = -13.8795758234
# GAP(1) = -13.9973156182 -13.8795758234 0.117739794793
# ITER = 12 ENTROPY = 0.927877309121
# -------------------------------------------
# Truncation error = 6.72601287269e-13
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 100 2 2 100 9180
# E0 = -13.9973156182
# E0 = -13.8795758235
# EXCITED OVERLAP(0) = -3.9307500397e-13
# E(1) = -13.8795758235
# GAP(1) = -13.9973156182 -13.8795758235 0.11773979474
# ITER = 13 ENTROPY = 0.855792271443
# -------------------------------------------
# Truncation error = 2.03084466036e-12
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 100 2 2 100 9451
# E0 = -13.9973156182
# E0 = -13.8795758235
# EXCITED OVERLAP(0) = 2.32789482135e-13
# E(1) = -13.8795758235
# GAP(1) = -13.9973156182 -13.8795758235 0.117739794732
# ITER = 14 ENTROPY = 0.960365743071
# -------------------------------------------
# Truncation error = 1.71890784005e-12
# -------------------------------------------
# FINAL SWEEP - LAST ITERATION
# NUMBER OF STATES: 100 2 2 100 9180
# E0 = -13.9973156182
# E0 = -13.8795758235
# EXCITED OVERLAP(0) = -3.69636450354e-13
# E(1) = -13.8795758235
# GAP(1) = -13.9973156182 -13.8795758235 0.117739794702
# ITER = 15 ENTROPY = 0.889751664102
# -------------------------------------------
# Truncation error = 3.82982945386e-12
# -------------------------------------------
# Checking if it is finished: not yet, next check in 60 seconds ( 0% done).
# Halted Simulation 1
# This task took 2 seconds.
# Checkpointing Simulation 1
# Finished with everything.

# %% [markdown]
# We finally load the measurements and print the results.

# %%
data = pyalps.loadEigenstateMeasurements(pyalps.getResultFiles(prefix='parm_spin_one_half_gap'))

energies = np.empty(0)
for s in data[0]:
    if s.props['observable'] == 'Energy':
        energies = s.y
    else:
        print(s.props['observable'], ':', s.y[0])
energies.sort()
print('Energies:', end=' ')
for e in energies:
    print(e, end=' ')
print('\nGap:', abs(energies[1]-energies[0]))
# Out:
# Truncation error : 3.829829453856734e-12
# Energies: -13.997315618200833 -13.879575823498984
# Gap: 0.11773979470184948

# %% [markdown]
# ### Method 2: Use Quantum Numbers

# %% [markdown]
# As we know, the ground state of a spin-1/2 chain exists in the spin-singlet sector. So, if we restrict the simulation in the magnetization `Sz_total = 0` sector, the lowest energy from the DMRG simulation will produce the spin-singlet ground state energy of the spin-1/2 chain. This is what we did in the previous simulation. If we restrict the simulation in the magnetization `Sz_total = 1` sector, the lowest energy from the DMRG simulation can only come from the spin-triplet state. Of course, the lowest energy from the `Sz_total = 1` sector will be the same as the first excited state energy from the `Sz_total = 0` sector, since without external magnetic fields, the 3 subsectors (`Sz_total = -1`, `Sz_total = 0`, and `Sz_total = 1`) of the triplet sector are degenerate.

# %% [markdown]
# We first load the libraries and prepare the input parameters.

# %%
import pyalps
import numpy as np

parms = []
for sz in [0,1]:
    parms.append( { 
        'LATTICE'                   : "open chain lattice", 
        'MODEL'                     : "spin",
        'CONSERVED_QUANTUMNUMBERS'  : 'N,Sz',
        'Sz_total'                  : sz,
        'J'                         : 1,
        'SWEEPS'                    : 4,
        'L'                         : 32,
        'MAXSTATES'                 : 40,
        'NUMBER_EIGENVALUES'        : 1
       } )

# %% [markdown]
# Notice that we now loop over `Sz_total = 0` and `Sz_total = 1`, which will produce two input parameter files for two DMRG simulations, as carried out in the following.

# %%
input_file = pyalps.writeInputFiles('parm_spin_one_half_triplet',parms)
res = pyalps.runApplication('dmrg',input_file,writexml=True)
# Out:
# dmrg parm_spin_one_half_triplet.in.xml --write-xml
# ALPS DMRG temporary files will be written to .
# ALPS/dmrg version 1.0.0 (2006/10/02)
#   Density Matrix Renormalization Group algorithm
#   for low-dimensional interacting systems.
#   available from http://alps.comp-phys.org/
#   copyright (c) 2006-2013 by Adrian E. Feiguin
#   for details see the publication:
#   A.F. Albuquerque et al., J. of Magn. and Magn. Materials 310, 1187 (2007).
#
# using the ALPS parallelizing scheduler
#   copyright (c) 1994-2006 by Matthias Troyer <troyer@comp-phys.org>.
#   see Lecture Notes in Computer Science, Vol. 1505, p. 191 (1998).
#
# based on the ALPS libraries version 2.3.0
#   available from http://alps.comp-phys.org/
#   copyright (c) 1994-2016 by the ALPS collaboration.
#   Consult the web page for license details.
#   For details see the publication:
#   B. Bauer et al., J. Stat. Mech. (2011) P05001.
#
# parsing task files ...
# ALPS DMRG temporary files will be written to /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/
# ALPS DMRG temporary files will be written to /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/
# ALPS DMRG temporary files will be written to /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/
# Starting task 1.
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_1_l43NnZh
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_1_rfPtIEr
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/iter_ALPSO245F0
# LEFT-TO-RIGHT sweep to get B(1)B(2)...B(L/2-1)
# WARMUP LEFT-TO-RIGHT ITERATION 1
# NUMBER OF STATES: 2 2 2 2 6
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/vectors_ALPSnCDFKn
# E0 = -1.61599612423
# ITER = 1 ENTROPY = 0.32384887062
# -------------------------------------------
# Truncation error = 8.67361737988e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/systemS7YLP5
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_2_lDimeXb
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_2_l7wlHL4
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_1_lPu90sm
# WARMUP LEFT-TO-RIGHT ITERATION 2
# NUMBER OF STATES: 4 2 2 2 10
# E0 = -1.92788624956
# ITER = 2 ENTROPY = 0.406479604728
# -------------------------------------------
# Truncation error = -8.32667268469e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_3_lGyroiF
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_3_l1Kkkw8
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_2_lCrwW1W
# WARMUP LEFT-TO-RIGHT ITERATION 3
# NUMBER OF STATES: 8 2 2 2 20
# E0 = -2.49357713098
# ITER = 3 ENTROPY = 0.37565597909
# -------------------------------------------
# Truncation error = 6.24500451352e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_4_lGrbqSP
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_4_lgzoVO5
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_3_l6Vtrdz
# WARMUP LEFT-TO-RIGHT ITERATION 4
# NUMBER OF STATES: 16 2 2 2 35
# E0 = -2.83623967883
# ITER = 4 ENTROPY = 0.39986343887
# -------------------------------------------
# Truncation error = 2.35922392733e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_5_l6kx8no
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_5_lzkSJTY
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_4_lMio5pW
# WARMUP LEFT-TO-RIGHT ITERATION 5
# NUMBER OF STATES: 20 2 2 2 43
# E0 = -3.35056486289
# ITER = 5 ENTROPY = 0.372216153818
# -------------------------------------------
# Truncation error = 2.60208521397e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_6_lkDpWmQ
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_6_lDfeldR
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_5_lq3Hyse
# WARMUP LEFT-TO-RIGHT ITERATION 6
# NUMBER OF STATES: 20 2 2 2 42
# E0 = -3.73220210039
# ITER = 6 ENTROPY = 0.387610562474
# -------------------------------------------
# Truncation error = -5.55111512313e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_7_laGVUYA
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_7_lsZ2CJ2
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_6_lcLVlVf
# WARMUP LEFT-TO-RIGHT ITERATION 7
# NUMBER OF STATES: 20 2 2 2 48
# E0 = -4.21792369993
# ITER = 7 ENTROPY = 0.36599751329
# -------------------------------------------
# Truncation error = 2.08166817117e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_8_lfJg1ua
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_8_lyWkoUT
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_7_lYVjQfw
# WARMUP LEFT-TO-RIGHT ITERATION 8
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -4.62006784043
# ITER = 8 ENTROPY = 0.376749166433
# -------------------------------------------
# Truncation error = -2.49800180541e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_9_lBrcTlp
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_9_lm0rnuu
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_8_lWooiom
# WARMUP LEFT-TO-RIGHT ITERATION 9
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -5.08790604062
# ITER = 9 ENTROPY = 0.365984976193
# -------------------------------------------
# Truncation error = 3.29597460436e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_10_lPgZZKx
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_10_lwWCHGG
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_9_lYIjDQR
# WARMUP LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 20 2 2 2 48
# E0 = -5.50765212024
# ITER = 10 ENTROPY = 0.380703556969
# -------------------------------------------
# Truncation error = 2.77555756156e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_11_leAR0J8
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_11_ld0wDKu
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_10_lRtJ3SJ
# WARMUP LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -5.960137073
# ITER = 11 ENTROPY = 0.3620744778
# -------------------------------------------
# Truncation error = -5.72458747072e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_12_lv4k6So
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_12_lyrRxc3
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_11_lKFC0Db
# WARMUP LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -6.38729203016
# ITER = 12 ENTROPY = 0.364390087388
# -------------------------------------------
# Truncation error = -5.55111512313e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_13_lZFnWl3
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_13_laCmAFn
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_12_l3ky0y0
# WARMUP LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -6.84457309219
# ITER = 13 ENTROPY = 0.378220301259
# -------------------------------------------
# Truncation error = 2.22044604925e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_14_lXGviS3
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_14_lUcqO2N
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_13_lh30veb
# WARMUP LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -7.26869274047
# ITER = 14 ENTROPY = 0.366777262715
# -------------------------------------------
# Truncation error = -4.85722573274e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_15_lYgv11K
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_15_lhw8DoP
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_14_lD4hrYx
# WARMUP LEFT-TO-RIGHT ITERATION 15
# NUMBER OF STATES: 20 2 2 2 54
# E0 = -7.71595859196
# ITER = 15 ENTROPY = 0.362301112602
# -------------------------------------------
# Truncation error = -1.73472347598e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_16_lvuxLgl
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_16_lZDzWd3
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_15_lydwODX
# WARMUP LEFT-TO-RIGHT ITERATION 16
# NUMBER OF STATES: 20 2 2 2 54
# E0 = -8.1496027346
# ITER = 16 ENTROPY = 0.36592185631
# -------------------------------------------
# Truncation error = -3.46944695195e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_17_liK53wF
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_17_l1UxNhf
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_16_l44UC2t
# WARMUP LEFT-TO-RIGHT ITERATION 17
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -8.59312979331
# ITER = 17 ENTROPY = 0.362149312739
# -------------------------------------------
# Truncation error = -3.79904441239e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_18_lHPgUdG
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_18_lZ8TGi2
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_17_lNntenn
# WARMUP LEFT-TO-RIGHT ITERATION 18
# NUMBER OF STATES: 20 2 2 2 48
# E0 = -9.03726576266
# ITER = 18 ENTROPY = 0.379670628701
# -------------------------------------------
# Truncation error = 4.85722573274e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_19_lwR0XWE
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_19_lkwW8CX
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_18_l1Y2EF4
# WARMUP LEFT-TO-RIGHT ITERATION 19
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -9.47385811499
# ITER = 19 ENTROPY = 0.372405437331
# -------------------------------------------
# Truncation error = 4.09394740331e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_20_lWSfD7X
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_20_lbDRP3m
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_19_lhPIjVA
# WARMUP LEFT-TO-RIGHT ITERATION 20
# NUMBER OF STATES: 20 2 2 2 46
# E0 = -9.91725146078
# ITER = 20 ENTROPY = 0.376423342882
# -------------------------------------------
# Truncation error = -1.52655665886e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_21_ljJ9Nu9
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_21_lVVB3ix
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_20_lcbI91l
# WARMUP LEFT-TO-RIGHT ITERATION 21
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -10.3583946676
# ITER = 21 ENTROPY = 0.37783032054
# -------------------------------------------
# Truncation error = 5.55111512313e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_22_lGXYVZE
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_22_lEZyj9y
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_21_l48lHbl
# WARMUP LEFT-TO-RIGHT ITERATION 22
# NUMBER OF STATES: 20 2 2 2 48
# E0 = -10.8032798875
# ITER = 22 ENTROPY = 0.38595273207
# -------------------------------------------
# Truncation error = -3.12250225676e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_23_lybBDMt
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_23_lnd27db
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_22_lhtP2hP
# WARMUP LEFT-TO-RIGHT ITERATION 23
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -11.2308335329
# ITER = 23 ENTROPY = 0.363406846088
# -------------------------------------------
# Truncation error = -1.90819582357e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_24_lq2MaxZ
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_24_lS31Q2g
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_23_lHdevBI
# WARMUP LEFT-TO-RIGHT ITERATION 24
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -11.6800103817
# ITER = 24 ENTROPY = 0.37563777338
# -------------------------------------------
# Truncation error = 1.11022302463e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_25_lWZ1SD5
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_25_lbkr3TN
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_24_lO0wLcr
# WARMUP LEFT-TO-RIGHT ITERATION 25
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -12.1099480907
# ITER = 25 ENTROPY = 0.36391374397
# -------------------------------------------
# Truncation error = -4.82253126322e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_26_lqa2o8D
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_26_lsPnfhX
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_25_lNL0Q3H
# WARMUP LEFT-TO-RIGHT ITERATION 26
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -12.5533095806
# ITER = 26 ENTROPY = 0.358559409449
# -------------------------------------------
# Truncation error = 0
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_27_lf8BPys
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_27_l161jMu
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_26_ll9Csip
# WARMUP LEFT-TO-RIGHT ITERATION 27
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -12.9948152161
# ITER = 27 ENTROPY = 0.373278519494
# -------------------------------------------
# Truncation error = 2.01227923213e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_28_lzxIA9w
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_28_lCmU3ur
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_27_lluWYZC
# WARMUP LEFT-TO-RIGHT ITERATION 28
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -13.4328603064
# ITER = 28 ENTROPY = 0.36152499445
# -------------------------------------------
# Truncation error = -7.6327832943e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_29_lEfyLsE
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_29_lr6Cm5U
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_28_lK598Ev
# RIGHT-TO-LEFT sweep to get B(1)B(2)...B(L/2-1)
# WARMUP RIGHT-TO-LEFT ITERATION 1
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -13.8722531738
# ITER = 1 ENTROPY = 0.363363954294
# -------------------------------------------
# Truncation error = -1.38777878078e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_2_rCSXsDv
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_2_rtVxJce
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_1_r0s5PAx
# WARMUP RIGHT-TO-LEFT ITERATION 2
# NUMBER OF STATES: 20 2 2 4 98
# E0 = -13.8825794024
# ITER = 2 ENTROPY = 0.649012769381
# -------------------------------------------
# Truncation error = -5.34511671035e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_3_rdZnjJ2
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_3_rbGlHBy
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_2_rRJ2j3F
# WARMUP RIGHT-TO-LEFT ITERATION 3
# NUMBER OF STATES: 20 2 2 8 180
# E0 = -13.8828631075
# ITER = 3 ENTROPY = 0.456383832428
# -------------------------------------------
# Truncation error = 1.18263322431e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_4_rqUvZMi
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_4_rMLS4gk
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_3_rrazJi0
# WARMUP RIGHT-TO-LEFT ITERATION 4
# NUMBER OF STATES: 20 2 2 16 345
# E0 = -13.8861735811
# ITER = 4 ENTROPY = 0.625029366144
# -------------------------------------------
# Truncation error = 9.36560219569e-11
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_5_rpO2Kgp
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_5_r9asmhk
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_4_rx0dk3x
# WARMUP RIGHT-TO-LEFT ITERATION 5
# NUMBER OF STATES: 20 2 2 20 446
# E0 = -13.8873539007
# ITER = 5 ENTROPY = 0.48642013501
# -------------------------------------------
# Truncation error = 1.29244260347e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_6_rsSAQf7
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_6_rZsI33h
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_5_rmhna3Q
# WARMUP RIGHT-TO-LEFT ITERATION 6
# NUMBER OF STATES: 20 2 2 20 464
# E0 = -13.894867258
# ITER = 6 ENTROPY = 0.623933081885
# -------------------------------------------
# Truncation error = 2.10914496588e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_7_rqwRD9O
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_7_rA7ufHj
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_6_rXdnDfO
# WARMUP RIGHT-TO-LEFT ITERATION 7
# NUMBER OF STATES: 20 2 2 20 432
# E0 = -13.8960181237
# ITER = 7 ENTROPY = 0.513657412448
# -------------------------------------------
# Truncation error = 4.1401671708e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_8_r8j48NJ
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_8_rHab3PK
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_7_rTF2Nlk
# WARMUP RIGHT-TO-LEFT ITERATION 8
# NUMBER OF STATES: 20 2 2 20 422
# E0 = -13.9070979955
# ITER = 8 ENTROPY = 0.655577583393
# -------------------------------------------
# Truncation error = 2.97239874207e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_9_r7GrGzs
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_9_r1H4hMN
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_8_rNVwT1P
# WARMUP RIGHT-TO-LEFT ITERATION 9
# NUMBER OF STATES: 20 2 2 20 438
# E0 = -13.9073483969
# ITER = 9 ENTROPY = 0.544160472911
# -------------------------------------------
# Truncation error = 3.06092573797e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_10_rYMxSF7
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_10_rytTiaj
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_9_rHglxu8
# WARMUP RIGHT-TO-LEFT ITERATION 10
# NUMBER OF STATES: 20 2 2 20 432
# E0 = -13.9099172236
# ITER = 10 ENTROPY = 0.633605054373
# -------------------------------------------
# Truncation error = 2.54061011378e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_11_rlhfn9F
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_11_rYJfzT7
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_10_rVewxqq
# WARMUP RIGHT-TO-LEFT ITERATION 11
# NUMBER OF STATES: 20 2 2 20 436
# E0 = -13.9112294518
# ITER = 11 ENTROPY = 0.546526147935
# -------------------------------------------
# Truncation error = 8.66910206141e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_12_rdbdkL2
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_12_rZgT67Y
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_11_r7soCGL
# WARMUP RIGHT-TO-LEFT ITERATION 12
# NUMBER OF STATES: 20 2 2 20 417
# E0 = -13.9157341439
# ITER = 12 ENTROPY = 0.624665912465
# -------------------------------------------
# Truncation error = 1.72255608215e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_13_r68GIcX
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_13_rqGCpO7
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_12_r7gFXCT
# WARMUP RIGHT-TO-LEFT ITERATION 13
# NUMBER OF STATES: 20 2 2 20 451
# E0 = -13.915926337
# ITER = 13 ENTROPY = 0.528405904985
# -------------------------------------------
# Truncation error = 5.29866464591e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_14_r5rgN1A
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_14_rHmLeLt
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_13_r3ZSM6I
# WARMUP RIGHT-TO-LEFT ITERATION 14
# NUMBER OF STATES: 20 2 2 20 438
# E0 = -13.9222929455
# ITER = 14 ENTROPY = 0.620281678547
# -------------------------------------------
# Truncation error = 4.9705658426e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_15_rdGpmLN
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_15_rR3Ttxq
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_14_rgdFQex
# WARMUP RIGHT-TO-LEFT ITERATION 15
# NUMBER OF STATES: 20 2 2 20 472
# E0 = -13.9240676439
# ITER = 15 ENTROPY = 0.531987652401
# -------------------------------------------
# Truncation error = 1.68628471189e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_16_roh0Jn4
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_16_rDa7O9u
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_15_rVXamvQ
# WARMUP RIGHT-TO-LEFT ITERATION 16
# NUMBER OF STATES: 20 2 2 20 446
# E0 = -13.9335785567
# ITER = 16 ENTROPY = 0.652883717507
# -------------------------------------------
# Truncation error = 3.11018595427e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_17_rNFxdye
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_17_rH8dvnS
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_16_r6aFfZ4
# WARMUP RIGHT-TO-LEFT ITERATION 17
# NUMBER OF STATES: 20 2 2 20 456
# E0 = -13.9353277574
# ITER = 17 ENTROPY = 0.55750827652
# -------------------------------------------
# Truncation error = 2.00794172279e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_18_riCJy6c
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_18_r11zMHT
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_17_rHxIG0W
# WARMUP RIGHT-TO-LEFT ITERATION 18
# NUMBER OF STATES: 20 2 2 20 460
# E0 = -13.9365306012
# ITER = 18 ENTROPY = 0.624528508317
# -------------------------------------------
# Truncation error = 2.63801203104e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_19_rV9kM3g
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_19_r9Y62dN
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_18_rJQQaJw
# WARMUP RIGHT-TO-LEFT ITERATION 19
# NUMBER OF STATES: 20 2 2 20 452
# E0 = -13.9389355711
# ITER = 19 ENTROPY = 0.541347352625
# -------------------------------------------
# Truncation error = 2.89854740752e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_20_r78cVvs
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_20_rRCSGVM
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_19_rpFosbZ
# WARMUP RIGHT-TO-LEFT ITERATION 20
# NUMBER OF STATES: 20 2 2 20 449
# E0 = -13.9469902363
# ITER = 20 ENTROPY = 0.653169528196
# -------------------------------------------
# Truncation error = 5.6668843252e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_21_r4kcQ5F
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_21_rrcrRTp
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_20_rXuxKgS
# WARMUP RIGHT-TO-LEFT ITERATION 21
# NUMBER OF STATES: 20 2 2 20 427
# E0 = -13.9479133645
# ITER = 21 ENTROPY = 0.538791048715
# -------------------------------------------
# Truncation error = 2.35148644507e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_22_rcAVzNi
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_22_rkfn874
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_21_r4UMOhJ
# WARMUP RIGHT-TO-LEFT ITERATION 22
# NUMBER OF STATES: 20 2 2 20 458
# E0 = -13.9568883889
# ITER = 22 ENTROPY = 0.677831092606
# -------------------------------------------
# Truncation error = 1.60124831146e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_23_rrKbrKn
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_23_rqW62wr
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_22_r7yESZT
# WARMUP RIGHT-TO-LEFT ITERATION 23
# NUMBER OF STATES: 20 2 2 20 424
# E0 = -13.9581811453
# ITER = 23 ENTROPY = 0.537877844307
# -------------------------------------------
# Truncation error = 3.51424309544e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_24_rPM4bDR
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_24_rA1ZUVd
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_23_rDkze1k
# WARMUP RIGHT-TO-LEFT ITERATION 24
# NUMBER OF STATES: 20 2 2 20 409
# E0 = -13.9695800118
# ITER = 24 ENTROPY = 0.718363384079
# -------------------------------------------
# Truncation error = 2.63823248187e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_25_rNehWKa
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_25_rDm1vMF
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_24_rDLHnA0
# WARMUP RIGHT-TO-LEFT ITERATION 25
# NUMBER OF STATES: 20 2 2 20 391
# E0 = -13.9701483976
# ITER = 25 ENTROPY = 0.538869054881
# -------------------------------------------
# Truncation error = 8.5678782559e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_26_rDSYflQ
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_26_rQMZI4F
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_25_r1IyGUG
# WARMUP RIGHT-TO-LEFT ITERATION 26
# NUMBER OF STATES: 16 2 2 20 322
# E0 = -13.9923791636
# ITER = 26 ENTROPY = 0.76525396795
# -------------------------------------------
# Truncation error = 1.82821774147e-09
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_27_r4Xv55w
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_27_rc0ul5b
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_26_rimEYlt
# WARMUP RIGHT-TO-LEFT ITERATION 27
# NUMBER OF STATES: 8 2 2 20 170
# E0 = -13.9923791627
# ITER = 27 ENTROPY = 0.543999744945
# -------------------------------------------
# Truncation error = -7.23098792181e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_28_ryonqYR
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_28_r3U6LTm
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_27_riK3iBE
# WARMUP RIGHT-TO-LEFT ITERATION 28
# NUMBER OF STATES: 4 2 2 20 88
# E0 = -13.9923791666
# ITER = 28 ENTROPY = 0.734050082591
# -------------------------------------------
# Truncation error = 1.04625509645e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_29_rdtu4HG
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_29_rfV6dNb
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_28_r5FFS59
# WARMUP LEFT-TO-RIGHT ITERATION 1
# NUMBER OF STATES: 2 2 2 20 48
# E0 = -13.9923791705
# ITER = 1 ENTROPY = 0.42496348726
# -------------------------------------------
# Truncation error = -2.671474153e-16
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 2
# NUMBER OF STATES: 4 2 2 20 88
# E0 = -13.9923791726
# ITER = 2 ENTROPY = 0.734044036452
# -------------------------------------------
# Truncation error = -6.94973592563e-17
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 3
# NUMBER OF STATES: 8 2 2 20 170
# E0 = -13.9923791781
# ITER = 3 ENTROPY = 0.544025146684
# -------------------------------------------
# Truncation error = -2.37713946826e-16
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 4
# NUMBER OF STATES: 16 2 2 20 322
# E0 = -13.992379189
# ITER = 4 ENTROPY = 0.765264908696
# -------------------------------------------
# Truncation error = 1.75933229991e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 5
# NUMBER OF STATES: 20 2 2 20 436
# E0 = -13.9924011365
# ITER = 5 ENTROPY = 0.606058162948
# -------------------------------------------
# Truncation error = 4.32659192868e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 6
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.9924224667
# ITER = 6 ENTROPY = 0.786745336815
# -------------------------------------------
# Truncation error = 7.74914464324e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 7
# NUMBER OF STATES: 20 2 2 20 442
# E0 = -13.9927307295
# ITER = 7 ENTROPY = 0.646677855642
# -------------------------------------------
# Truncation error = 1.80300524739e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 8
# NUMBER OF STATES: 20 2 2 20 412
# E0 = -13.9927519413
# ITER = 8 ENTROPY = 0.803526956219
# -------------------------------------------
# Truncation error = 2.27209128804e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 9
# NUMBER OF STATES: 20 2 2 20 407
# E0 = -13.9933088354
# ITER = 9 ENTROPY = 0.67539467781
# -------------------------------------------
# Truncation error = 4.74319602686e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.9933485304
# ITER = 10 ENTROPY = 0.816851907601
# -------------------------------------------
# Truncation error = 3.05746409433e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 20 2 2 20 442
# E0 = -13.9939822806
# ITER = 11 ENTROPY = 0.693190973193
# -------------------------------------------
# Truncation error = 5.3036843715e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.9940143463
# ITER = 12 ENTROPY = 0.824936266998
# -------------------------------------------
# Truncation error = 4.66400753603e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 20 2 2 20 440
# E0 = -13.9944183397
# ITER = 13 ENTROPY = 0.704158054394
# -------------------------------------------
# Truncation error = 7.62937602304e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 20 2 2 20 412
# E0 = -13.9944380298
# ITER = 14 ENTROPY = 0.829847032587
# -------------------------------------------
# Truncation error = 6.78468886817e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 15
# NUMBER OF STATES: 20 2 2 20 442
# E0 = -13.9949549569
# ITER = 15 ENTROPY = 0.707906385146
# -------------------------------------------
# Truncation error = 7.49816005164e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 16
# NUMBER OF STATES: 20 2 2 20 393
# E0 = -13.9950447026
# ITER = 16 ENTROPY = 0.830818527473
# -------------------------------------------
# Truncation error = 9.48994235595e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 17
# NUMBER OF STATES: 20 2 2 20 425
# E0 = -13.9958249216
# ITER = 17 ENTROPY = 0.709058778042
# -------------------------------------------
# Truncation error = 8.25708364158e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 18
# NUMBER OF STATES: 20 2 2 20 393
# E0 = -13.9958482386
# ITER = 18 ENTROPY = 0.830017694283
# -------------------------------------------
# Truncation error = 8.3153296645e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 19
# NUMBER OF STATES: 20 2 2 20 414
# E0 = -13.996239018
# ITER = 19 ENTROPY = 0.700772919015
# -------------------------------------------
# Truncation error = 5.54104589613e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 20
# NUMBER OF STATES: 20 2 2 20 412
# E0 = -13.9964125043
# ITER = 20 ENTROPY = 0.823732489227
# -------------------------------------------
# Truncation error = 4.99808685901e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 21
# NUMBER OF STATES: 20 2 2 20 425
# E0 = -13.9965787949
# ITER = 21 ENTROPY = 0.683287062993
# -------------------------------------------
# Truncation error = 4.89919459078e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 22
# NUMBER OF STATES: 20 2 2 20 400
# E0 = -13.9965881118
# ITER = 22 ENTROPY = 0.811073128546
# -------------------------------------------
# Truncation error = 3.00618243587e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 23
# NUMBER OF STATES: 20 2 2 20 414
# E0 = -13.9967947421
# ITER = 23 ENTROPY = 0.656944905504
# -------------------------------------------
# Truncation error = 1.53207602318e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 24
# NUMBER OF STATES: 20 2 2 20 412
# E0 = -13.99710133
# ITER = 24 ENTROPY = 0.795527429438
# -------------------------------------------
# Truncation error = 5.23801538298e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 25
# NUMBER OF STATES: 20 2 2 20 428
# E0 = -13.997299285
# ITER = 25 ENTROPY = 0.617263884544
# -------------------------------------------
# Truncation error = 7.49002833909e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 26
# NUMBER OF STATES: 20 2 2 16 322
# E0 = -13.9973025384
# ITER = 26 ENTROPY = 0.770838511119
# -------------------------------------------
# Truncation error = 2.56557714429e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 27
# NUMBER OF STATES: 20 2 2 8 170
# E0 = -13.9973025579
# ITER = 27 ENTROPY = 0.550025777294
# -------------------------------------------
# Truncation error = -1.40312648839e-16
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 28
# NUMBER OF STATES: 20 2 2 4 88
# E0 = -13.9973025693
# ITER = 28 ENTROPY = 0.736413110069
# -------------------------------------------
# Truncation error = -2.58040117052e-17
# -------------------------------------------
# NEW SWEEP 1 5 10
# ===========================================
# NEW SWEEP
# ===========================================
# RIGHT-TO-LEFT ITERATION 1
# NUMBER OF STATES: 20 2 2 2 48
# E0 = -13.997302573
# ITER = 1 ENTROPY = 0.427223510841
# -------------------------------------------
# Truncation error = -3.46944695195e-17
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 2
# NUMBER OF STATES: 20 2 2 4 88
# E0 = -13.9973025762
# ITER = 2 ENTROPY = 0.736414916758
# -------------------------------------------
# Truncation error = 0.00080021794287
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 3
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9954028247
# ITER = 3 ENTROPY = 0.533477201471
# -------------------------------------------
# Truncation error = 0.000113628871897
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 4
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9951646609
# ITER = 4 ENTROPY = 0.762236925363
# -------------------------------------------
# Truncation error = 0.00143797486654
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 5
# NUMBER OF STATES: 20 2 2 5 114
# E0 = -13.992124845
# ITER = 5 ENTROPY = 0.576148867869
# -------------------------------------------
# Truncation error = 0.000213578510853
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 6
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9917075551
# ITER = 6 ENTROPY = 0.774231208676
# -------------------------------------------
# Truncation error = 0.00173228519797
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 7
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9881900566
# ITER = 7 ENTROPY = 0.594273812625
# -------------------------------------------
# Truncation error = 0.000260445180779
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 8
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9876899323
# ITER = 8 ENTROPY = 0.779250935732
# -------------------------------------------
# Truncation error = 0.00183326333891
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 9
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9840179928
# ITER = 9 ENTROPY = 0.601690454361
# -------------------------------------------
# Truncation error = 0.000277677031009
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 10
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9834864312
# ITER = 10 ENTROPY = 0.780776634835
# -------------------------------------------
# Truncation error = 0.00184339177617
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 11
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9798056315
# ITER = 11 ENTROPY = 0.603933127802
# -------------------------------------------
# Truncation error = 0.000279849631154
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 12
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9792678948
# ITER = 12 ENTROPY = 0.780394606142
# -------------------------------------------
# Truncation error = 0.00180933824588
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 13
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9756462396
# ITER = 13 ENTROPY = 0.60326535764
# -------------------------------------------
# Truncation error = 0.000273780786458
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 14
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9751164127
# ITER = 14 ENTROPY = 0.778802759465
# -------------------------------------------
# Truncation error = 0.00175104435969
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 15
# NUMBER OF STATES: 20 2 2 5 114
# E0 = -13.9715898657
# ITER = 15 ENTROPY = 0.600496025018
# -------------------------------------------
# Truncation error = 0.000261967974978
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 16
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9710769532
# ITER = 16 ENTROPY = 0.776302447209
# -------------------------------------------
# Truncation error = 0.00167661844949
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 17
# NUMBER OF STATES: 20 2 2 5 114
# E0 = -13.9676695679
# ITER = 17 ENTROPY = 0.595752562123
# -------------------------------------------
# Truncation error = 0.000245665031939
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 18
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9671833689
# ITER = 18 ENTROPY = 0.772874240623
# -------------------------------------------
# Truncation error = 0.0015843145248
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 19
# NUMBER OF STATES: 20 2 2 5 114
# E0 = -13.9639201763
# ITER = 19 ENTROPY = 0.588596638492
# -------------------------------------------
# Truncation error = 0.000223272647307
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 20
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9634704082
# ITER = 20 ENTROPY = 0.768372240927
# -------------------------------------------
# Truncation error = 0.00147046278659
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 21
# NUMBER OF STATES: 20 2 2 5 114
# E0 = -13.9603842968
# ITER = 21 ENTROPY = 0.578080978103
# -------------------------------------------
# Truncation error = 0.00019425205077
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 22
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.959984204
# ITER = 22 ENTROPY = 0.762377476343
# -------------------------------------------
# Truncation error = 0.00132500955586
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 23
# NUMBER OF STATES: 20 2 2 5 114
# E0 = -13.9571276638
# ITER = 23 ENTROPY = 0.562218204167
# -------------------------------------------
# Truncation error = 0.000156049864755
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 24
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9567951738
# ITER = 24 ENTROPY = 0.754047477975
# -------------------------------------------
# Truncation error = 0.00112989879446
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 25
# NUMBER OF STATES: 20 2 2 5 109
# E0 = -13.9542585086
# ITER = 25 ENTROPY = 0.53698511888
# -------------------------------------------
# Truncation error = 0.000106859311488
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 26
# NUMBER OF STATES: 16 2 2 5 85
# E0 = -13.9540181329
# ITER = 26 ENTROPY = 0.741716973998
# -------------------------------------------
# Truncation error = 0.000855038871182
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 27
# NUMBER OF STATES: 8 2 2 5 45
# E0 = -13.9519662162
# ITER = 27 ENTROPY = 0.492554918456
# -------------------------------------------
# Truncation error = 4.82735813186e-05
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 28
# NUMBER OF STATES: 4 2 2 5 24
# E0 = -13.9518467039
# ITER = 28 ENTROPY = 0.722276329336
# -------------------------------------------
# Truncation error = 0.000460950131128
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 1
# NUMBER OF STATES: 2 2 2 5 13
# E0 = -13.9505906017
# ITER = 1 ENTROPY = 0.397739797728
# -------------------------------------------
# Truncation error = 3.46944695195e-18
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 2
# NUMBER OF STATES: 4 2 2 5 24
# E0 = -13.9518466967
# ITER = 2 ENTROPY = 0.722289966804
# -------------------------------------------
# Truncation error = 2.00658717073e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 3
# NUMBER OF STATES: 8 2 2 5 45
# E0 = -13.9519662053
# ITER = 3 ENTROPY = 0.492424555484
# -------------------------------------------
# Truncation error = -2.28983498829e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 4
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9540125892
# ITER = 4 ENTROPY = 0.741647648764
# -------------------------------------------
# Truncation error = 8.78203759713e-17
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 5
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9542506977
# ITER = 5 ENTROPY = 0.536811659987
# -------------------------------------------
# Truncation error = 1.2490009027e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 6
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9567688584
# ITER = 6 ENTROPY = 0.753700838543
# -------------------------------------------
# Truncation error = -3.41957365202e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 7
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9570943172
# ITER = 7 ENTROPY = 0.561701671472
# -------------------------------------------
# Truncation error = 5.55111512313e-17
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 8
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9599123049
# ITER = 8 ENTROPY = 0.761596917894
# -------------------------------------------
# Truncation error = -9.90960785652e-17
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 9
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9602991025
# ITER = 9 ENTROPY = 0.576896273035
# -------------------------------------------
# Truncation error = 6.24500451352e-17
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9633204432
# ITER = 10 ENTROPY = 0.766983667234
# -------------------------------------------
# Truncation error = 1.6707555478e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.963749927
# ITER = 11 ENTROPY = 0.586528027799
# -------------------------------------------
# Truncation error = -1.87350135405e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9669175149
# ITER = 12 ENTROPY = 0.770743793701
# -------------------------------------------
# Truncation error = -1.15792792021e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9673764061
# ITER = 13 ENTROPY = 0.592627380215
# -------------------------------------------
# Truncation error = -1.38777878078e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9706543432
# ITER = 14 ENTROPY = 0.773394772855
# -------------------------------------------
# Truncation error = 1.33898968302e-17
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 15
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9711327614
# ITER = 15 ENTROPY = 0.59624925225
# -------------------------------------------
# Truncation error = -3.33066907388e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 16
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9744951254
# ITER = 16 ENTROPY = 0.775156708002
# -------------------------------------------
# Truncation error = 3.9876955904e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 17
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.97498477
# ITER = 17 ENTROPY = 0.597882029338
# -------------------------------------------
# Truncation error = 1.38777878078e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 18
# NUMBER OF STATES: 10 2 2 5 56
# E0 = -13.9784080267
# ITER = 18 ENTROPY = 0.776069459185
# -------------------------------------------
# Truncation error = -2.29850860567e-17
# ...
# LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 40 2 2 35 1391
# E0 = -13.8795757462
# ITER = 10 ENTROPY = 0.666731197015
# -------------------------------------------
# Truncation error = 1.9322437628e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 40 2 2 35 1390
# E0 = -13.8795757519
# ITER = 11 ENTROPY = 0.788216141055
# -------------------------------------------
# Truncation error = 3.81346010325e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 40 2 2 35 1385
# E0 = -13.8795757545
# ITER = 12 ENTROPY = 0.668651375393
# -------------------------------------------
# Truncation error = 2.71115480919e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 40 2 2 35 1385
# E0 = -13.8795757628
# ITER = 13 ENTROPY = 0.811820762642
# -------------------------------------------
# Truncation error = 5.70696448271e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 40 2 2 35 1330
# E0 = -13.8795757665
# ITER = 14 ENTROPY = 0.669800877245
# -------------------------------------------
# Truncation error = 2.64132562848e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 15
# NUMBER OF STATES: 40 2 2 35 1385
# E0 = -13.8795757785
# ITER = 15 ENTROPY = 0.819708213247
# -------------------------------------------
# Truncation error = 5.17796396929e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 16
# NUMBER OF STATES: 40 2 2 35 1348
# E0 = -13.8795757828
# ITER = 16 ENTROPY = 0.669801164516
# -------------------------------------------
# Truncation error = 2.61310352062e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 17
# NUMBER OF STATES: 40 2 2 35 1386
# E0 = -13.879575791
# ITER = 17 ENTROPY = 0.811821298873
# -------------------------------------------
# Truncation error = 5.76703485247e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 18
# NUMBER OF STATES: 40 2 2 35 1333
# E0 = -13.879575793
# ITER = 18 ENTROPY = 0.668652113641
# -------------------------------------------
# Truncation error = 2.68543726071e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 19
# NUMBER OF STATES: 40 2 2 35 1365
# E0 = -13.8795757985
# ITER = 19 ENTROPY = 0.788217044462
# -------------------------------------------
# Truncation error = 3.86814801629e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 20
# NUMBER OF STATES: 40 2 2 35 1397
# E0 = -13.8795758005
# ITER = 20 ENTROPY = 0.666732180355
# -------------------------------------------
# Truncation error = 1.96723769961e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 21
# NUMBER OF STATES: 40 2 2 35 1400
# E0 = -13.8795758029
# ITER = 21 ENTROPY = 0.749994237803
# -------------------------------------------
# Truncation error = 1.84561406326e-10
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 22
# NUMBER OF STATES: 40 2 2 35 1400
# E0 = -13.8795758036
# ITER = 22 ENTROPY = 0.664908529673
# -------------------------------------------
# Truncation error = 7.51942740726e-11
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 23
# NUMBER OF STATES: 40 2 2 35 1376
# E0 = -13.879575804
# ITER = 23 ENTROPY = 0.698649019112
# -------------------------------------------
# Truncation error = 5.69659005174e-11
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 24
# NUMBER OF STATES: 40 2 2 35 1340
# E0 = -13.8795758042
# ITER = 24 ENTROPY = 0.663708880297
# -------------------------------------------
# Truncation error = 1.77700596412e-11
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 25
# NUMBER OF STATES: 40 2 2 32 1190
# E0 = -13.8795758041
# ITER = 25 ENTROPY = 0.633805633065
# -------------------------------------------
# Truncation error = 7.93620457948e-13
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 26
# NUMBER OF STATES: 40 2 2 16 616
# E0 = -13.8795758041
# ITER = 26 ENTROPY = 0.663125522187
# -------------------------------------------
# Truncation error = 5.6736999472e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 27
# NUMBER OF STATES: 40 2 2 8 322
# E0 = -13.8795758041
# ITER = 27 ENTROPY = 0.54984731494
# -------------------------------------------
# Truncation error = -5.44366965551e-17
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 28
# NUMBER OF STATES: 40 2 2 4 170
# E0 = -13.8795758041
# ITER = 28 ENTROPY = 0.662032907173
# -------------------------------------------
# Truncation error = -3.55658970157e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 1
# NUMBER OF STATES: 40 2 2 2 94
# E0 = -13.8795758041
# ITER = 1 ENTROPY = 0.420344445161
# -------------------------------------------
# Truncation error = 9.71445146547e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 2
# NUMBER OF STATES: 40 2 2 4 170
# E0 = -13.8795758041
# ITER = 2 ENTROPY = 0.662032918812
# -------------------------------------------
# Truncation error = -2.88180937447e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 3
# NUMBER OF STATES: 40 2 2 8 322
# E0 = -13.8795758041
# ITER = 3 ENTROPY = 0.54984737692
# -------------------------------------------
# Truncation error = 1.73958544509e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 4
# NUMBER OF STATES: 40 2 2 16 616
# E0 = -13.8795758041
# ITER = 4 ENTROPY = 0.663125708635
# -------------------------------------------
# Truncation error = -6.48468034416e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 5
# NUMBER OF STATES: 40 2 2 32 1190
# E0 = -13.8795758041
# ITER = 5 ENTROPY = 0.633806012335
# -------------------------------------------
# Truncation error = 7.79705500062e-13
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 6
# NUMBER OF STATES: 40 2 2 40 1532
# E0 = -13.8795758042
# ITER = 6 ENTROPY = 0.663709408071
# -------------------------------------------
# Truncation error = 1.78454276951e-11
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 7
# NUMBER OF STATES: 40 2 2 40 1544
# E0 = -13.8795758044
# ITER = 7 ENTROPY = 0.698649668935
# -------------------------------------------
# Truncation error = 5.7559662833e-11
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 8
# NUMBER OF STATES: 40 2 2 40 1568
# E0 = -13.8795758044
# ITER = 8 ENTROPY = 0.664909472709
# -------------------------------------------
# Truncation error = 8.16278423828e-11
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 9
# NUMBER OF STATES: 40 2 2 40 1564
# E0 = -13.8795758048
# ITER = 9 ENTROPY = 0.749995243505
# -------------------------------------------
# Truncation error = 1.90961068844e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 10
# NUMBER OF STATES: 40 2 2 40 1584
# E0 = -13.8795758049
# ITER = 10 ENTROPY = 0.666733644823
# -------------------------------------------
# Truncation error = 2.07688453702e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 11
# NUMBER OF STATES: 40 2 2 40 1565
# E0 = -13.8795758057
# ITER = 11 ENTROPY = 0.788218602419
# -------------------------------------------
# Truncation error = 4.07445286277e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 12
# NUMBER OF STATES: 40 2 2 40 1519
# E0 = -13.8795758052
# ITER = 12 ENTROPY = 0.668654138552
# -------------------------------------------
# Truncation error = 2.80662576588e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 13
# NUMBER OF STATES: 40 2 2 40 1576
# E0 = -13.8795758066
# ITER = 13 ENTROPY = 0.811823391609
# -------------------------------------------
# Truncation error = 6.34709630809e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 14
# NUMBER OF STATES: 40 2 2 40 1479
# E0 = -13.8795758053
# ITER = 14 ENTROPY = 0.669803725641
# -------------------------------------------
# Truncation error = 2.86886425024e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 15
# NUMBER OF STATES: 40 2 2 40 1574
# E0 = -13.8795758062
# ITER = 15 ENTROPY = 0.819710633604
# -------------------------------------------
# Truncation error = 6.53865658255e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 16
# NUMBER OF STATES: 40 2 2 40 1479
# E0 = -13.8795758053
# ITER = 16 ENTROPY = 0.669803744966
# -------------------------------------------
# Truncation error = 2.87366787929e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 17
# NUMBER OF STATES: 40 2 2 40 1576
# E0 = -13.8795758067
# ITER = 17 ENTROPY = 0.811823422262
# -------------------------------------------
# Truncation error = 6.35912814075e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 18
# NUMBER OF STATES: 40 2 2 40 1519
# E0 = -13.8795758053
# ITER = 18 ENTROPY = 0.668654194717
# -------------------------------------------
# Truncation error = 2.80279600203e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 19
# NUMBER OF STATES: 40 2 2 40 1577
# E0 = -13.8795758058
# ITER = 19 ENTROPY = 0.788218660597
# -------------------------------------------
# Truncation error = 4.10446452448e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 20
# NUMBER OF STATES: 40 2 2 40 1584
# E0 = -13.879575805
# ITER = 20 ENTROPY = 0.666733717318
# -------------------------------------------
# Truncation error = 1.98428996626e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 21
# NUMBER OF STATES: 40 2 2 40 1548
# E0 = -13.879575805
# ITER = 21 ENTROPY = 0.749995299651
# -------------------------------------------
# Truncation error = 1.87872146384e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 22
# NUMBER OF STATES: 40 2 2 40 1568
# E0 = -13.8795758046
# ITER = 22 ENTROPY = 0.664909549441
# -------------------------------------------
# Truncation error = 8.38652234477e-11
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 23
# NUMBER OF STATES: 40 2 2 40 1544
# E0 = -13.8795758046
# ITER = 23 ENTROPY = 0.698649725921
# -------------------------------------------
# Truncation error = 5.75913852823e-11
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 24
# NUMBER OF STATES: 40 2 2 40 1532
# E0 = -13.8795758044
# ITER = 24 ENTROPY = 0.663709472526
# -------------------------------------------
# Truncation error = 1.78072504252e-11
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 25
# NUMBER OF STATES: 32 2 2 40 1190
# E0 = -13.8795758044
# ITER = 25 ENTROPY = 0.633806064347
# -------------------------------------------
# Truncation error = 7.76959891272e-13
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 26
# NUMBER OF STATES: 16 2 2 40 616
# E0 = -13.8795758043
# ITER = 26 ENTROPY = 0.663125748775
# -------------------------------------------
# Truncation error = 9.24416440779e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 27
# NUMBER OF STATES: 8 2 2 40 317
# E0 = -13.8795758043
# ITER = 27 ENTROPY = 0.549847419457
# -------------------------------------------
# Truncation error = -2.89801801166e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 28
# NUMBER OF STATES: 4 2 2 40 167
# E0 = -13.8795758043
# ITER = 28 ENTROPY = 0.662032945638
# -------------------------------------------
# Truncation error = -1.91836021894e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 1
# NUMBER OF STATES: 2 2 2 40 88
# E0 = -13.8795758043
# ITER = 1 ENTROPY = 0.420344470999
# -------------------------------------------
# Truncation error = -1.11022302463e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 2
# NUMBER OF STATES: 4 2 2 40 167
# E0 = -13.8795758043
# ITER = 2 ENTROPY = 0.66203294688
# -------------------------------------------
# Truncation error = 2.37873956643e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 3
# NUMBER OF STATES: 8 2 2 40 317
# E0 = -13.8795758043
# ITER = 3 ENTROPY = 0.549847427825
# -------------------------------------------
# Truncation error = 9.1904768843e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 4
# NUMBER OF STATES: 16 2 2 40 616
# E0 = -13.8795758043
# ITER = 4 ENTROPY = 0.663125766066
# -------------------------------------------
# Truncation error = -8.06426495888e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 5
# NUMBER OF STATES: 32 2 2 40 1190
# E0 = -13.8795758044
# ITER = 5 ENTROPY = 0.633806092418
# -------------------------------------------
# Truncation error = 7.68242122072e-13
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 6
# NUMBER OF STATES: 40 2 2 40 1532
# E0 = -13.8795758044
# ITER = 6 ENTROPY = 0.663709510336
# -------------------------------------------
# Truncation error = 1.78361314054e-11
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 7
# NUMBER OF STATES: 40 2 2 40 1544
# E0 = -13.8795758046
# ITER = 7 ENTROPY = 0.698649773499
# -------------------------------------------
# Truncation error = 5.76184666927e-11
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 8
# NUMBER OF STATES: 40 2 2 40 1568
# E0 = -13.8795758046
# ITER = 8 ENTROPY = 0.664909616549
# -------------------------------------------
# Truncation error = 8.38685035418e-11
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 9
# NUMBER OF STATES: 40 2 2 40 1548
# E0 = -13.879575805
# ITER = 9 ENTROPY = 0.749995375092
# -------------------------------------------
# Truncation error = 1.87807061108e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 40 2 2 40 1584
# E0 = -13.8795758051
# ITER = 10 ENTROPY = 0.666733823612
# -------------------------------------------
# Truncation error = 1.97673179537e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 40 2 2 40 1565
# E0 = -13.8795758059
# ITER = 11 ENTROPY = 0.788218771256
# -------------------------------------------
# Truncation error = 4.06666549177e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 40 2 2 40 1519
# E0 = -13.8795758053
# ITER = 12 ENTROPY = 0.668654341638
# -------------------------------------------
# Truncation error = 2.81046597915e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 40 2 2 40 1576
# E0 = -13.8795758068
# ITER = 13 ENTROPY = 0.811823569486
# -------------------------------------------
# Truncation error = 6.35137522601e-10
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 40 2 2 40 1479
# E0 = -13.8795758054
# ITER = 14 ENTROPY = 0.669803935112
# -------------------------------------------
# Truncation error = 2.87883660847e-10
# -------------------------------------------
# FINAL SWEEP - LAST ITERATION
# NUMBER OF STATES: 40 2 2 40 1574
# E0 = -13.8795758063
# ITER = 15 ENTROPY = 0.819710800121
# -------------------------------------------
# Truncation error = 6.54270141776e-10
# -------------------------------------------
# Checking if it is finished: not yet, next check in 60 seconds ( 0% done).
# Halted Simulation 2
# This task took 1 seconds.
# Checkpointing Simulation 1
# Checkpointing Simulation 2
# Finished with everything.

# %% [markdown]
# We then load the measurements and print the results.

# %%
data = pyalps.loadEigenstateMeasurements(pyalps.getResultFiles(prefix='parm_spin_one_half_triplet'))

energies = {}
for run in data:
    print('S_z =', run[0].props['Sz_total'])
    for s in run:
        print('\t', s.props['observable'], ':', s.y[0])
        if s.props['observable'] == 'Energy':
            sz = s.props['Sz_total']
            energies[sz] = s.y[0]

print('Gap:', energies[1]-energies[0])
# Out:
# S_z = 0.0
# 	 Energy : -13.99731559507624
# 	 Truncation error : 5.68519406884438e-10
# S_z = 1.0
# 	 Energy : -13.879575806349818
# 	 Truncation error : 6.542701417759682e-10
# Gap: 0.11773978872642132

# %% [markdown]
# Let us compare the energies and gap from both methods. Do they agree with each other?
