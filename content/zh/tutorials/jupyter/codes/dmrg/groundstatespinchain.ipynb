# %% [markdown]
# ## Ground State Energy of a Spin Chain

# %% [markdown]
# In this example, we will use Density Matrix Renormalization Group (DMRG) simulations to study the ground state energy of a 32-site spin-half Heisenberg chain with open boundary conditions. We will look at the convergence of the ground state energy as well as the decay of the truncation errors as functions of the iteration numbers.

# %%
import pyalps
import numpy as np
import matplotlib.pyplot as plt
import pyalps.plot

parms = [ { 
        'LATTICE'                   : "open chain lattice", 
        'MODEL'                     : "spin",
        'CONSERVED_QUANTUMNUMBERS'  : 'N,Sz',
        'Sz_total'                  : 0,
        'J'                         : 1,
        'SWEEPS'                    : 4,
        'NUMBER_EIGENVALUES'        : 1,
        'L'                         : 32,
        'MAXSTATES'                 : 100
       } ]

input_file = pyalps.writeInputFiles('parm_spin_one_half',parms)
res = pyalps.runApplication('dmrg',input_file,writexml=True)
# Out:
# dmrg parm_spin_one_half.in.xml --write-xml
# ALPS DMRG temporary files will be written to .
# ALPS/dmrg version 1.0.0 (2006/10/02)
#   Density Matrix Renormalization Group algorithm
#   for low-dimensional interacting systems.
#   available from http://alps.comp-phys.org/
#   copyright (c) 2006-2013 by Adrian E. Feiguin
#   for details see the publication:
#   A.F. Albuquerque et al., J. of Magn. and Magn. Materials 310, 1187 (2007).
#
# using the ALPS parallelizing scheduler
#   copyright (c) 1994-2006 by Matthias Troyer <troyer@comp-phys.org>.
#   see Lecture Notes in Computer Science, Vol. 1505, p. 191 (1998).
#
# based on the ALPS libraries version 2.3.0
#   available from http://alps.comp-phys.org/
#   copyright (c) 1994-2016 by the ALPS collaboration.
#   Consult the web page for license details.
#   For details see the publication:
#   B. Bauer et al., J. Stat. Mech. (2011) P05001.
#
# parsing task files ...
# ALPS DMRG temporary files will be written to /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/
# ALPS DMRG temporary files will be written to /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/
# Starting task 1.
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_1_lRJoN8q
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_1_r64ec4V
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/iter_ALPSfOfNDV
# LEFT-TO-RIGHT sweep to get B(1)B(2)...B(L/2-1)
# WARMUP LEFT-TO-RIGHT ITERATION 1
# NUMBER OF STATES: 2 2 2 2 6
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/vectors_ALPSCz3x1w
# E0 = -1.61276078872
# ITER = 1 ENTROPY = 0.270056013075
# -------------------------------------------
# Truncation error = -5.55111512313e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/system0Buvxu
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_2_lCzKP4u
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_2_lgCLQmx
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_1_l2smK92
# WARMUP LEFT-TO-RIGHT ITERATION 2
# NUMBER OF STATES: 4 2 2 2 10
# E0 = -1.92788620585
# ITER = 2 ENTROPY = 0.406427984999
# -------------------------------------------
# Truncation error = -5.55111512313e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_3_lvz2JGX
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_3_lkCYQyE
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_2_lGO1R02
# WARMUP LEFT-TO-RIGHT ITERATION 3
# NUMBER OF STATES: 8 2 2 2 20
# E0 = -2.49357713333
# ITER = 3 ENTROPY = 0.375586645999
# -------------------------------------------
# Truncation error = -1.73472347598e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_4_l3JsjsJ
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_4_lhBK0aQ
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_3_le57FDW
# WARMUP LEFT-TO-RIGHT ITERATION 4
# NUMBER OF STATES: 16 2 2 2 35
# E0 = -2.8362396745
# ITER = 4 ENTROPY = 0.399890319827
# -------------------------------------------
# Truncation error = 2.77555756156e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_5_lTJ8267
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_5_lym8xxi
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_4_lxw9vP1
# WARMUP LEFT-TO-RIGHT ITERATION 5
# NUMBER OF STATES: 20 2 2 2 41
# E0 = -3.3431093216
# ITER = 5 ENTROPY = 0.358262467393
# -------------------------------------------
# Truncation error = -2.11636264069e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_6_lpEzQeE
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_6_l6uTFPS
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_5_lyDNbTO
# WARMUP LEFT-TO-RIGHT ITERATION 6
# NUMBER OF STATES: 20 2 2 2 35
# E0 = -3.73222669987
# ITER = 6 ENTROPY = 0.383963370005
# -------------------------------------------
# Truncation error = 0
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_7_lfukds4
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_7_lXVnxFm
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_6_lcuqROv
# WARMUP LEFT-TO-RIGHT ITERATION 7
# NUMBER OF STATES: 20 2 2 2 42
# E0 = -4.20992273063
# ITER = 7 ENTROPY = 0.362820076103
# -------------------------------------------
# Truncation error = -3.57353036051e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_8_lED78sD
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_8_lIojHKd
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_7_lLh1pJa
# WARMUP LEFT-TO-RIGHT ITERATION 8
# NUMBER OF STATES: 20 2 2 2 44
# E0 = -4.62221983389
# ITER = 8 ENTROPY = 0.381661775554
# -------------------------------------------
# Truncation error = -3.1918911958e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_9_l4J5ANf
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_9_l91LXPz
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_8_l21Kifa
# WARMUP LEFT-TO-RIGHT ITERATION 9
# NUMBER OF STATES: 20 2 2 2 49
# E0 = -5.0885147516
# ITER = 9 ENTROPY = 0.370913750659
# -------------------------------------------
# Truncation error = -1.6826817717e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_10_lEOI6nI
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_10_lMC7GN4
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_9_lDs73yv
# WARMUP LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 20 2 2 2 49
# E0 = -5.50464171298
# ITER = 10 ENTROPY = 0.373388982207
# -------------------------------------------
# Truncation error = 2.08166817117e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_11_lRF29j1
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_11_lGlCeOC
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_10_lJAArx7
# WARMUP LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -5.96012226918
# ITER = 11 ENTROPY = 0.367288498627
# -------------------------------------------
# Truncation error = -4.51028103754e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_12_lOEEKYm
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_12_ldBuLLl
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_11_lvwXJL9
# WARMUP LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -6.38942320752
# ITER = 12 ENTROPY = 0.376802108364
# -------------------------------------------
# Truncation error = -1.80411241502e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_13_lgvHjjm
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_13_lTgwgww
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_12_lKMmleZ
# WARMUP LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 20 2 2 2 46
# E0 = -6.83391903572
# ITER = 13 ENTROPY = 0.3592975383
# -------------------------------------------
# Truncation error = -4.68375338514e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_14_lD9JzDl
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_14_lHj7NiC
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_13_l2F8Cq2
# WARMUP LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 20 2 2 2 47
# E0 = -7.26650832124
# ITER = 14 ENTROPY = 0.360367771724
# -------------------------------------------
# Truncation error = -2.08166817117e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_15_lCKjNM2
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_15_ll8GgoF
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_14_lZW556E
# WARMUP LEFT-TO-RIGHT ITERATION 15
# NUMBER OF STATES: 20 2 2 2 49
# E0 = -7.71076633675
# ITER = 15 ENTROPY = 0.360061254922
# -------------------------------------------
# Truncation error = -3.05311331772e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_16_lQjvZWz
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_16_l2Un8Jl
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_15_l5RWVfT
# WARMUP LEFT-TO-RIGHT ITERATION 16
# NUMBER OF STATES: 20 2 2 2 43
# E0 = -8.14592159542
# ITER = 16 ENTROPY = 0.359838760272
# -------------------------------------------
# Truncation error = 1.2490009027e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_17_lHNOzk3
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_17_lRASLg1
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_16_lYykrwW
# WARMUP LEFT-TO-RIGHT ITERATION 17
# NUMBER OF STATES: 20 2 2 2 51
# E0 = -8.58822391738
# ITER = 17 ENTROPY = 0.357082624398
# -------------------------------------------
# Truncation error = 5.06539254985e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_18_lXlwYqx
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_18_lVdpjUR
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_17_lpf46mE
# WARMUP LEFT-TO-RIGHT ITERATION 18
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -9.03119726064
# ITER = 18 ENTROPY = 0.374614376666
# -------------------------------------------
# Truncation error = 4.85722573274e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_19_lS3n9uR
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_19_lDp5t0Z
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_18_leH6FuM
# WARMUP LEFT-TO-RIGHT ITERATION 19
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -9.4661054338
# ITER = 19 ENTROPY = 0.358855152184
# -------------------------------------------
# Truncation error = 4.85722573274e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_20_lZfdVN8
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_20_l0JTy3S
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_19_lC4PnkI
# WARMUP LEFT-TO-RIGHT ITERATION 20
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -9.91101328467
# ITER = 20 ENTROPY = 0.372703048572
# -------------------------------------------
# Truncation error = 4.85722573274e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_21_lzdUANm
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_21_lYEBD6I
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_20_lxvVsNQ
# WARMUP LEFT-TO-RIGHT ITERATION 21
# NUMBER OF STATES: 20 2 2 2 54
# E0 = -10.347854978
# ITER = 21 ENTROPY = 0.367588484608
# -------------------------------------------
# Truncation error = -1.7694179455e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_22_llQqsah
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_22_lACXE7Y
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_21_l510r8f
# WARMUP LEFT-TO-RIGHT ITERATION 22
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -10.792385176
# ITER = 22 ENTROPY = 0.376736411686
# -------------------------------------------
# Truncation error = -2.15105711021e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_23_lotZNBs
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_23_lOaj384
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_22_ljhZedr
# WARMUP LEFT-TO-RIGHT ITERATION 23
# NUMBER OF STATES: 20 2 2 2 54
# E0 = -11.2330813149
# ITER = 23 ENTROPY = 0.382013004309
# -------------------------------------------
# Truncation error = 5.23886489745e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_24_lDvPukY
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_24_lwPWYhE
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_23_lBUOV4m
# WARMUP LEFT-TO-RIGHT ITERATION 24
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -11.6695969083
# ITER = 24 ENTROPY = 0.367974328136
# -------------------------------------------
# Truncation error = 8.32667268469e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_25_ly9NC42
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_25_l8a440m
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_24_luz0I7f
# WARMUP LEFT-TO-RIGHT ITERATION 25
# NUMBER OF STATES: 20 2 2 2 54
# E0 = -12.1164874935
# ITER = 25 ENTROPY = 0.386208893958
# -------------------------------------------
# Truncation error = 3.15719672628e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_26_lxTiuGz
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_26_ldk0iIM
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_25_ld8EYSV
# WARMUP LEFT-TO-RIGHT ITERATION 26
# NUMBER OF STATES: 20 2 2 2 48
# E0 = -12.5478664692
# ITER = 26 ENTROPY = 0.368113562055
# -------------------------------------------
# Truncation error = -1.45716771982e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_27_lk74iTV
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_27_l0IUNZo
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_26_lbLJdvY
# WARMUP LEFT-TO-RIGHT ITERATION 27
# NUMBER OF STATES: 20 2 2 2 52
# E0 = -12.9889060083
# ITER = 27 ENTROPY = 0.364869243549
# -------------------------------------------
# Truncation error = -3.24393290008e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_28_lgcboGs
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_28_lg7frrX
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_27_lH7Uemj
# WARMUP LEFT-TO-RIGHT ITERATION 28
# NUMBER OF STATES: 20 2 2 2 50
# E0 = -13.4257879438
# ITER = 28 ENTROPY = 0.360348900797
# -------------------------------------------
# Truncation error = 2.08166817117e-17
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_29_lUTnCc8
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_29_lTMbEOl
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_28_lioZ5G5
# RIGHT-TO-LEFT sweep to get B(1)B(2)...B(L/2-1)
# WARMUP RIGHT-TO-LEFT ITERATION 1
# NUMBER OF STATES: 20 2 2 2 48
# E0 = -13.8705421846
# ITER = 1 ENTROPY = 0.369067723831
# -------------------------------------------
# Truncation error = 3.81639164715e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_2_rpFCNuH
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_2_rOZZwqu
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_1_ryMZmiN
# WARMUP RIGHT-TO-LEFT ITERATION 2
# NUMBER OF STATES: 20 2 2 4 96
# E0 = -13.8765800992
# ITER = 2 ENTROPY = 0.642423626116
# -------------------------------------------
# Truncation error = 4.4647445463e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_3_rrWQQ3k
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_3_rO10wdc
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_2_rp9mVBA
# WARMUP RIGHT-TO-LEFT ITERATION 3
# NUMBER OF STATES: 20 2 2 8 180
# E0 = -13.8769580253
# ITER = 3 ENTROPY = 0.446190900916
# -------------------------------------------
# Truncation error = -1.59471104738e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_4_rCHwaQ3
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_4_r6aFVB8
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_3_r5p1jTk
# WARMUP RIGHT-TO-LEFT ITERATION 4
# NUMBER OF STATES: 20 2 2 16 345
# E0 = -13.8902113702
# ITER = 4 ENTROPY = 0.667162670659
# -------------------------------------------
# Truncation error = 7.74513676935e-11
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_5_r3A10oJ
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_5_r1lhJeE
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_4_rNrfzEl
# WARMUP RIGHT-TO-LEFT ITERATION 5
# NUMBER OF STATES: 20 2 2 20 478
# E0 = -13.8910022398
# ITER = 5 ENTROPY = 0.514920184842
# -------------------------------------------
# Truncation error = 2.77086717808e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_6_rt3vaAP
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_6_rxX95Cc
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_5_rIqWpJ4
# WARMUP RIGHT-TO-LEFT ITERATION 6
# NUMBER OF STATES: 20 2 2 20 460
# E0 = -13.8943038423
# ITER = 6 ENTROPY = 0.654680775072
# -------------------------------------------
# Truncation error = 1.24595781826e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_7_rJHDMPa
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_7_rozbzJK
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_6_rb69Evh
# WARMUP RIGHT-TO-LEFT ITERATION 7
# NUMBER OF STATES: 20 2 2 20 478
# E0 = -13.8955656985
# ITER = 7 ENTROPY = 0.534016117236
# -------------------------------------------
# Truncation error = 1.51468970706e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_8_r7h1hdr
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_8_rXMmV90
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_7_rST7MpJ
# WARMUP RIGHT-TO-LEFT ITERATION 8
# NUMBER OF STATES: 20 2 2 20 484
# E0 = -13.89765804
# ITER = 8 ENTROPY = 0.630587560071
# -------------------------------------------
# Truncation error = 4.56399044425e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_9_rJ5xjrV
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_9_r2GQj1s
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_8_rlgTXfg
# WARMUP RIGHT-TO-LEFT ITERATION 9
# NUMBER OF STATES: 20 2 2 20 482
# E0 = -13.8986000911
# ITER = 9 ENTROPY = 0.526327071754
# -------------------------------------------
# Truncation error = 2.85444160242e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_10_rifiwAQ
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_10_reWROTA
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_9_rVMe81v
# WARMUP RIGHT-TO-LEFT ITERATION 10
# NUMBER OF STATES: 20 2 2 20 460
# E0 = -13.9030526259
# ITER = 10 ENTROPY = 0.614111692323
# -------------------------------------------
# Truncation error = 1.84267078592e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_11_riM81SD
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_11_rmfRC0v
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_10_rd0dFA6
# WARMUP RIGHT-TO-LEFT ITERATION 11
# NUMBER OF STATES: 20 2 2 20 461
# E0 = -13.9044837997
# ITER = 11 ENTROPY = 0.526163181867
# -------------------------------------------
# Truncation error = 3.45963098571e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_12_rMyUgfv
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_12_rmApsfq
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_11_r0rFm4E
# WARMUP RIGHT-TO-LEFT ITERATION 12
# NUMBER OF STATES: 20 2 2 20 447
# E0 = -13.9109534694
# ITER = 12 ENTROPY = 0.614052104485
# -------------------------------------------
# Truncation error = 2.31121701205e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_13_rTdsHuU
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_13_rLA3gKJ
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_12_rRtadLC
# WARMUP RIGHT-TO-LEFT ITERATION 13
# NUMBER OF STATES: 20 2 2 20 442
# E0 = -13.9116019929
# ITER = 13 ENTROPY = 0.52035082224
# -------------------------------------------
# Truncation error = 8.01084347452e-11
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_14_r4Uvk8L
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_14_rVd5Fqx
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_13_rmffsbA
# WARMUP RIGHT-TO-LEFT ITERATION 14
# NUMBER OF STATES: 20 2 2 20 410
# E0 = -13.9179559949
# ITER = 14 ENTROPY = 0.60824579607
# -------------------------------------------
# Truncation error = 1.57192807815e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_15_rZFjIBY
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_15_rmN00Os
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_14_rW73oa6
# WARMUP RIGHT-TO-LEFT ITERATION 15
# NUMBER OF STATES: 20 2 2 20 440
# E0 = -13.9200805319
# ITER = 15 ENTROPY = 0.527438770044
# -------------------------------------------
# Truncation error = 1.05713555906e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_16_rbR2OFP
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_16_rZy0R98
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_15_rcS9Ta6
# WARMUP RIGHT-TO-LEFT ITERATION 16
# NUMBER OF STATES: 20 2 2 20 452
# E0 = -13.9262574871
# ITER = 16 ENTROPY = 0.609372879225
# -------------------------------------------
# Truncation error = 2.43289266771e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_17_r4V40FG
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_17_rQhn5MD
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_16_rnPBVfJ
# WARMUP RIGHT-TO-LEFT ITERATION 17
# NUMBER OF STATES: 20 2 2 20 421
# E0 = -13.9290729986
# ITER = 17 ENTROPY = 0.537936281155
# -------------------------------------------
# Truncation error = 1.82299082917e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_18_rwPqjNY
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_18_rSaNiF9
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_17_rzTmJFK
# WARMUP RIGHT-TO-LEFT ITERATION 18
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.9366234538
# ITER = 18 ENTROPY = 0.633910700136
# -------------------------------------------
# Truncation error = 1.98217928079e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_19_rtMTcls
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_19_rbdIojd
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_18_rAMy165
# WARMUP RIGHT-TO-LEFT ITERATION 19
# NUMBER OF STATES: 20 2 2 20 424
# E0 = -13.9378378395
# ITER = 19 ENTROPY = 0.542619023503
# -------------------------------------------
# Truncation error = 1.63882331197e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_20_rcRW8n5
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_20_rZxG4BU
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_19_ruR4zvE
# WARMUP RIGHT-TO-LEFT ITERATION 20
# NUMBER OF STATES: 20 2 2 20 426
# E0 = -13.9460085629
# ITER = 20 ENTROPY = 0.656312000003
# -------------------------------------------
# Truncation error = 2.28275465371e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_21_rtQG36q
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_21_rnV5zG0
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_20_rVgjKS4
# WARMUP RIGHT-TO-LEFT ITERATION 21
# NUMBER OF STATES: 20 2 2 20 426
# E0 = -13.9479205842
# ITER = 21 ENTROPY = 0.553662144824
# -------------------------------------------
# Truncation error = 1.29238285264e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_22_rbPsZLr
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_22_rNhCniK
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_21_rrx56eH
# WARMUP RIGHT-TO-LEFT ITERATION 22
# NUMBER OF STATES: 20 2 2 20 398
# E0 = -13.9517616926
# ITER = 22 ENTROPY = 0.657919527449
# -------------------------------------------
# Truncation error = 2.83898145877e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_23_r6fB80C
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_23_ry0867V
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_22_rLyqO9f
# WARMUP RIGHT-TO-LEFT ITERATION 23
# NUMBER OF STATES: 20 2 2 20 364
# E0 = -13.9525300593
# ITER = 23 ENTROPY = 0.530460991278
# -------------------------------------------
# Truncation error = 1.33386378352e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_24_r8doZTY
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_24_rRmgioB
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_23_rR1JCWp
# WARMUP RIGHT-TO-LEFT ITERATION 24
# NUMBER OF STATES: 20 2 2 20 341
# E0 = -13.9629868369
# ITER = 24 ENTROPY = 0.689478633894
# -------------------------------------------
# Truncation error = 1.14609767857e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_25_rWSAfje
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_25_rlXvz6q
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_24_r9Ox7fN
# WARMUP RIGHT-TO-LEFT ITERATION 25
# NUMBER OF STATES: 20 2 2 20 384
# E0 = -13.9634796332
# ITER = 25 ENTROPY = 0.51393482953
# -------------------------------------------
# Truncation error = 5.69742725148e-10
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_26_rYWkGLA
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_26_rBNPW36
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_25_rx905wC
# WARMUP RIGHT-TO-LEFT ITERATION 26
# NUMBER OF STATES: 16 2 2 20 308
# E0 = -13.9906204068
# ITER = 26 ENTROPY = 0.762307475642
# -------------------------------------------
# Truncation error = 1.69626158107e-09
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_27_rpoRWzj
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_27_rNrPe5E
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_26_rlJUWXQ
# WARMUP RIGHT-TO-LEFT ITERATION 27
# NUMBER OF STATES: 8 2 2 20 170
# E0 = -13.9906204095
# ITER = 27 ENTROPY = 0.541748780296
# -------------------------------------------
# Truncation error = 5.33329001283e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_28_rsVVIcK
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_28_rCl82zz
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_27_rgBHYIY
# WARMUP RIGHT-TO-LEFT ITERATION 28
# NUMBER OF STATES: 4 2 2 20 88
# E0 = -13.9906204357
# ITER = 28 ENTROPY = 0.732648829767
# -------------------------------------------
# Truncation error = -1.76345483355e-16
# -------------------------------------------
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/block_ALPS_29_rYabLqv
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/rho_ALPS_29_rvEzH15
# Creating temp file /var/folders/xs/_qcnmpw97nbgn1zd4hygvcpr0000gp/T/gs_ALPS_28_rDS9uTk
# WARMUP LEFT-TO-RIGHT ITERATION 1
# NUMBER OF STATES: 2 2 2 20 50
# E0 = -13.9906204365
# ITER = 1 ENTROPY = 0.423991192773
# -------------------------------------------
# Truncation error = 8.32667268469e-17
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 2
# NUMBER OF STATES: 4 2 2 20 88
# E0 = -13.9906204373
# ITER = 2 ENTROPY = 0.732656110515
# -------------------------------------------
# Truncation error = 6.67597487708e-17
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 3
# NUMBER OF STATES: 8 2 2 20 170
# E0 = -13.9906204429
# ITER = 3 ENTROPY = 0.541607602919
# -------------------------------------------
# Truncation error = 1.76940947517e-17
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 4
# NUMBER OF STATES: 16 2 2 20 308
# E0 = -13.9906204539
# ITER = 4 ENTROPY = 0.762347790917
# -------------------------------------------
# Truncation error = 1.55316002258e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 5
# NUMBER OF STATES: 20 2 2 20 436
# E0 = -13.9908661787
# ITER = 5 ENTROPY = 0.603840345217
# -------------------------------------------
# Truncation error = 4.27043505423e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 6
# NUMBER OF STATES: 20 2 2 20 419
# E0 = -13.9909366913
# ITER = 6 ENTROPY = 0.784172094442
# -------------------------------------------
# Truncation error = 8.58213937643e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 7
# NUMBER OF STATES: 20 2 2 20 430
# E0 = -13.9913743166
# ITER = 7 ENTROPY = 0.64393891484
# -------------------------------------------
# Truncation error = 2.02114587335e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 8
# NUMBER OF STATES: 20 2 2 20 412
# E0 = -13.9914402365
# ITER = 8 ENTROPY = 0.800380326608
# -------------------------------------------
# Truncation error = 2.23089023728e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 9
# NUMBER OF STATES: 20 2 2 20 430
# E0 = -13.9918626479
# ITER = 9 ENTROPY = 0.671666656909
# -------------------------------------------
# Truncation error = 4.29348958613e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 20 2 2 20 412
# E0 = -13.9919097147
# ITER = 10 ENTROPY = 0.81338135135
# -------------------------------------------
# Truncation error = 4.40902750596e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 20 2 2 20 417
# E0 = -13.9920812128
# ITER = 11 ENTROPY = 0.685076927627
# -------------------------------------------
# Truncation error = 4.96627007715e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 20 2 2 20 412
# E0 = -13.9921011185
# ITER = 12 ENTROPY = 0.817198882586
# -------------------------------------------
# Truncation error = 5.47328458041e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 20 2 2 20 442
# E0 = -13.9924304317
# ITER = 13 ENTROPY = 0.69134337804
# -------------------------------------------
# Truncation error = 4.0741988173e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 20 2 2 20 438
# E0 = -13.9928095833
# ITER = 14 ENTROPY = 0.821763397032
# -------------------------------------------
# Truncation error = 2.62229599438e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 15
# NUMBER OF STATES: 20 2 2 20 450
# E0 = -13.9935063246
# ITER = 15 ENTROPY = 0.696943640588
# -------------------------------------------
# Truncation error = 3.7711689591e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 16
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.9940359452
# ITER = 16 ENTROPY = 0.823830488904
# -------------------------------------------
# Truncation error = 2.50044877589e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 17
# NUMBER OF STATES: 20 2 2 20 440
# E0 = -13.99448929
# ITER = 17 ENTROPY = 0.692839830556
# -------------------------------------------
# Truncation error = 5.73168226853e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 18
# NUMBER OF STATES: 20 2 2 20 412
# E0 = -13.9948341187
# ITER = 18 ENTROPY = 0.822323028745
# -------------------------------------------
# Truncation error = 4.62966021359e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 19
# NUMBER OF STATES: 20 2 2 20 447
# E0 = -13.9961503947
# ITER = 19 ENTROPY = 0.697980023646
# -------------------------------------------
# Truncation error = 4.59643820198e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 20
# NUMBER OF STATES: 20 2 2 20 419
# E0 = -13.9967164059
# ITER = 20 ENTROPY = 0.823962452214
# -------------------------------------------
# Truncation error = 4.63154529893e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 21
# NUMBER OF STATES: 20 2 2 20 452
# E0 = -13.9971187481
# ITER = 21 ENTROPY = 0.686544481256
# -------------------------------------------
# Truncation error = 4.82372557871e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 22
# NUMBER OF STATES: 20 2 2 20 431
# E0 = -13.9971353561
# ITER = 22 ENTROPY = 0.813464888059
# -------------------------------------------
# Truncation error = 2.36865978949e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 23
# NUMBER OF STATES: 20 2 2 20 450
# E0 = -13.997256073
# ITER = 23 ENTROPY = 0.659498776575
# -------------------------------------------
# Truncation error = 2.4834644754e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 24
# NUMBER OF STATES: 20 2 2 20 419
# E0 = -13.9972645253
# ITER = 24 ENTROPY = 0.796024697376
# -------------------------------------------
# Truncation error = 1.03757206723e-08
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 25
# NUMBER OF STATES: 20 2 2 20 450
# E0 = -13.9972904444
# ITER = 25 ENTROPY = 0.616883397722
# -------------------------------------------
# Truncation error = 7.33859386524e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 26
# NUMBER OF STATES: 20 2 2 16 322
# E0 = -13.9972922198
# ITER = 26 ENTROPY = 0.770762474897
# -------------------------------------------
# Truncation error = 2.24047742652e-09
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 27
# NUMBER OF STATES: 20 2 2 8 170
# E0 = -13.9972922562
# ITER = 27 ENTROPY = 0.550012154355
# -------------------------------------------
# Truncation error = -1.97607545578e-16
# -------------------------------------------
# WARMUP LEFT-TO-RIGHT ITERATION 28
# NUMBER OF STATES: 20 2 2 4 90
# E0 = -13.9972922731
# ITER = 28 ENTROPY = 0.7364018522
# -------------------------------------------
# Truncation error = 1.22894316251e-16
# -------------------------------------------
# NEW SWEEP 1 12 25
# ===========================================
# NEW SWEEP
# ===========================================
# RIGHT-TO-LEFT ITERATION 1
# NUMBER OF STATES: 20 2 2 2 46
# E0 = -13.9972922783
# ITER = 1 ENTROPY = 0.427200452171
# -------------------------------------------
# Truncation error = -1.5959455979e-16
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 2
# NUMBER OF STATES: 20 2 2 4 90
# E0 = -13.9972922836
# ITER = 2 ENTROPY = 0.736404376626
# -------------------------------------------
# Truncation error = 6.90636783873e-17
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 3
# NUMBER OF STATES: 20 2 2 8 170
# E0 = -13.9972922895
# ITER = 3 ENTROPY = 0.54996964742
# -------------------------------------------
# Truncation error = 1.05381858348e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 4
# NUMBER OF STATES: 20 2 2 12 251
# E0 = -13.9972884611
# ITER = 4 ENTROPY = 0.770762834888
# -------------------------------------------
# Truncation error = 1.04957464248e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 5
# NUMBER OF STATES: 20 2 2 12 265
# E0 = -13.99728551
# ITER = 5 ENTROPY = 0.617022887934
# -------------------------------------------
# Truncation error = 3.82767856661e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 6
# NUMBER OF STATES: 20 2 2 12 251
# E0 = -13.9972732504
# ITER = 6 ENTROPY = 0.796249875866
# -------------------------------------------
# Truncation error = 3.48058533133e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 7
# NUMBER OF STATES: 20 2 2 12 265
# E0 = -13.9972641552
# ITER = 7 ENTROPY = 0.659524987335
# -------------------------------------------
# Truncation error = 7.53733972212e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 8
# NUMBER OF STATES: 20 2 2 12 251
# E0 = -13.997241826
# ITER = 8 ENTROPY = 0.814380164176
# -------------------------------------------
# Truncation error = 6.11233460835e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 9
# NUMBER OF STATES: 20 2 2 12 265
# E0 = -13.9972261232
# ITER = 9 ENTROPY = 0.687454480326
# -------------------------------------------
# Truncation error = 1.09834101439e-05
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 10
# NUMBER OF STATES: 20 2 2 12 251
# E0 = -13.9971947833
# ITER = 10 ENTROPY = 0.826754907171
# -------------------------------------------
# Truncation error = 8.24503209106e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 11
# NUMBER OF STATES: 20 2 2 12 267
# E0 = -13.9971738382
# ITER = 11 ENTROPY = 0.704912526324
# -------------------------------------------
# Truncation error = 1.3654303134e-05
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 12
# NUMBER OF STATES: 20 2 2 12 251
# E0 = -13.9971369157
# ITER = 12 ENTROPY = 0.834174031971
# -------------------------------------------
# Truncation error = 9.59941178053e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 13
# NUMBER OF STATES: 20 2 2 12 265
# E0 = -13.9971135349
# ITER = 13 ENTROPY = 0.714332689471
# -------------------------------------------
# Truncation error = 1.51809879048e-05
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 14
# NUMBER OF STATES: 20 2 2 12 251
# E0 = -13.997072737
# ITER = 14 ENTROPY = 0.83762090377
# -------------------------------------------
# Truncation error = 1.02769259291e-05
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 15
# NUMBER OF STATES: 20 2 2 12 265
# E0 = -13.9970473826
# ITER = 15 ENTROPY = 0.717016998229
# -------------------------------------------
# Truncation error = 1.54437555928e-05
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 16
# NUMBER OF STATES: 20 2 2 12 251
# E0 = -13.9970060435
# ITER = 16 ENTROPY = 0.83719257415
# -------------------------------------------
# Truncation error = 1.00160939857e-05
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 17
# NUMBER OF STATES: 20 2 2 12 265
# E0 = -13.9969813629
# ITER = 17 ENTROPY = 0.713219118845
# -------------------------------------------
# Truncation error = 1.46655686507e-05
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 18
# NUMBER OF STATES: 20 2 2 12 251
# E0 = -13.9969415457
# ITER = 18 ENTROPY = 0.832992566213
# -------------------------------------------
# Truncation error = 9.05158308278e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 19
# NUMBER OF STATES: 20 2 2 12 265
# E0 = -13.9969185818
# ITER = 19 ENTROPY = 0.702720772046
# -------------------------------------------
# Truncation error = 1.26136884261e-05
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 20
# NUMBER OF STATES: 20 2 2 12 251
# E0 = -13.9968829478
# ITER = 20 ENTROPY = 0.824949987831
# -------------------------------------------
# Truncation error = 7.19765252797e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 21
# NUMBER OF STATES: 20 2 2 12 265
# E0 = -13.9968642507
# ITER = 21 ENTROPY = 0.684639027578
# -------------------------------------------
# Truncation error = 9.69445425241e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 22
# NUMBER OF STATES: 20 2 2 12 251
# E0 = -13.9968358255
# ITER = 22 ENTROPY = 0.812313542542
# -------------------------------------------
# Truncation error = 4.91304234986e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 23
# NUMBER OF STATES: 20 2 2 12 265
# E0 = -13.9968226544
# ITER = 23 ENTROPY = 0.656444717091
# -------------------------------------------
# Truncation error = 6.39060743492e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 24
# NUMBER OF STATES: 20 2 2 12 251
# E0 = -13.9968028249
# ITER = 24 ENTROPY = 0.794370392261
# -------------------------------------------
# Truncation error = 2.57751077475e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 25
# NUMBER OF STATES: 20 2 2 12 255
# E0 = -13.9967955301
# ITER = 25 ENTROPY = 0.614610667374
# -------------------------------------------
# Truncation error = 3.22447856392e-06
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 26
# NUMBER OF STATES: 16 2 2 12 196
# E0 = -13.9967847099
# ITER = 26 ENTROPY = 0.7696166093
# -------------------------------------------
# Truncation error = 7.64235145292e-07
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 27
# NUMBER OF STATES: 8 2 2 12 105
# E0 = -13.9967823993
# ITER = 27 ENTROPY = 0.548434310109
# -------------------------------------------
# Truncation error = 8.96222273032e-07
# -------------------------------------------
# RIGHT-TO-LEFT ITERATION 28
# NUMBER OF STATES: 4 2 2 12 55
# E0 = -13.9967789809
# ITER = 28 ENTROPY = 0.735955468019
# -------------------------------------------
# Truncation error = 1.22894316251e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 1
# NUMBER OF STATES: 2 2 2 12 30
# E0 = -13.9967789833
# ITER = 1 ENTROPY = 0.426551120898
# -------------------------------------------
# Truncation error = -2.15105711021e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 2
# NUMBER OF STATES: 4 2 2 12 55
# E0 = -13.9967789842
# ITER = 2 ENTROPY = 0.735935250652
# -------------------------------------------
# Truncation error = -3.18321757842e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 3
# NUMBER OF STATES: 8 2 2 12 105
# E0 = -13.996782398
# ITER = 3 ENTROPY = 0.548301182273
# -------------------------------------------
# Truncation error = -2.57554687763e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 4
# NUMBER OF STATES: 16 2 2 12 196
# E0 = -13.9967847294
# ITER = 4 ENTROPY = 0.769487985588
# -------------------------------------------
# Truncation error = -8.73866951023e-17
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 5
# NUMBER OF STATES: 25 2 2 12 310
# E0 = -13.9967955452
# ITER = 5 ENTROPY = 0.614305033493
# -------------------------------------------
# Truncation error = 2.59084085159e-17
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 6
# NUMBER OF STATES: 25 2 2 12 312
# E0 = -13.9968028625
# ITER = 6 ENTROPY = 0.794156257814
# -------------------------------------------
# Truncation error = 2.23996168836e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 7
# NUMBER OF STATES: 25 2 2 12 310
# E0 = -13.9968227937
# ITER = 7 ENTROPY = 0.65600892763
# -------------------------------------------
# Truncation error = -2.8919060072e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 8
# NUMBER OF STATES: 25 2 2 12 307
# E0 = -13.9968361246
# ITER = 8 ENTROPY = 0.812001833701
# -------------------------------------------
# Truncation error = -1.28369537222e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 9
# NUMBER OF STATES: 25 2 2 12 312
# E0 = -13.996864918
# ITER = 9 ENTROPY = 0.684011872123
# -------------------------------------------
# Truncation error = -1.44962065626e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 25 2 2 12 312
# E0 = -13.9968839292
# ITER = 10 ENTROPY = 0.824520946081
# -------------------------------------------
# Truncation error = 1.51137782844e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 25 2 2 12 310
# E0 = -13.9969201009
# ITER = 11 ENTROPY = 0.702004522809
# -------------------------------------------
# Truncation error = 1.29052669294e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 25 2 2 12 307
# E0 = -13.9969436311
# ITER = 12 ENTROPY = 0.832650934659
# -------------------------------------------
# Truncation error = -7.2424705122e-17
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 25 2 2 12 310
# E0 = -13.9969849396
# ITER = 13 ENTROPY = 0.712671983295
# -------------------------------------------
# Truncation error = -1.82265396623e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 25 2 2 12 307
# E0 = -13.9970112076
# ITER = 14 ENTROPY = 0.83691378726
# -------------------------------------------
# Truncation error = 1.32706345912e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 15
# NUMBER OF STATES: 25 2 2 12 302
# E0 = -13.997054844
# ITER = 15 ENTROPY = 0.716550021459
# -------------------------------------------
# Truncation error = -1.22548726809e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 16
# NUMBER OF STATES: 25 2 2 12 312
# E0 = -13.9970818214
# ITER = 16 ENTROPY = 0.837405249635
# -------------------------------------------
# Truncation error = -1.75207071074e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 17
# NUMBER OF STATES: 25 2 2 12 310
# E0 = -13.9971247346
# ITER = 17 ENTROPY = 0.714012578369
# -------------------------------------------
# Truncation error = 2.99015759391e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 18
# NUMBER OF STATES: 25 2 2 12 307
# E0 = -13.9971502336
# ITER = 18 ENTROPY = 0.834059116247
# -------------------------------------------
# Truncation error = 6.50521303491e-19
# -------------------------------------------
# ...
# E0 = -13.9973156182
# ITER = 10 ENTROPY = 0.828567576642
# -------------------------------------------
# Truncation error = 4.38348520999e-15
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 100 2 2 87 7931
# E0 = -13.9973156182
# ITER = 11 ENTROPY = 0.707404753143
# -------------------------------------------
# Truncation error = 1.33765026267e-14
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 100 2 2 87 7924
# E0 = -13.9973156182
# ITER = 12 ENTROPY = 0.836949178942
# -------------------------------------------
# Truncation error = 1.91636325841e-14
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 100 2 2 87 7931
# E0 = -13.9973156182
# ITER = 13 ENTROPY = 0.717770125835
# -------------------------------------------
# Truncation error = 2.97088692989e-14
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 100 2 2 87 7769
# E0 = -13.9973156182
# ITER = 14 ENTROPY = 0.841033950604
# -------------------------------------------
# Truncation error = 3.10016555054e-14
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 15
# NUMBER OF STATES: 100 2 2 87 7931
# E0 = -13.9973156182
# ITER = 15 ENTROPY = 0.721125545884
# -------------------------------------------
# Truncation error = 3.84131904674e-14
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 16
# NUMBER OF STATES: 100 2 2 87 7800
# E0 = -13.9973156182
# ITER = 16 ENTROPY = 0.84103395064
# -------------------------------------------
# Truncation error = 3.05836412039e-14
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 17
# NUMBER OF STATES: 100 2 2 87 7931
# E0 = -13.9973156182
# ITER = 17 ENTROPY = 0.7177701259
# -------------------------------------------
# Truncation error = 3.05770793937e-14
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 18
# NUMBER OF STATES: 100 2 2 87 7800
# E0 = -13.9973156182
# ITER = 18 ENTROPY = 0.83694917904
# -------------------------------------------
# Truncation error = 1.93953985247e-14
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 19
# NUMBER OF STATES: 100 2 2 87 7931
# E0 = -13.9973156182
# ITER = 19 ENTROPY = 0.707404753254
# -------------------------------------------
# Truncation error = 1.37053716553e-14
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 20
# NUMBER OF STATES: 100 2 2 87 7849
# E0 = -13.9973156182
# ITER = 20 ENTROPY = 0.82856757677
# -------------------------------------------
# Truncation error = 5.01263196968e-15
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 21
# NUMBER OF STATES: 100 2 2 87 7931
# E0 = -13.9973156182
# ITER = 21 ENTROPY = 0.689026944666
# -------------------------------------------
# Truncation error = 3.19889734655e-15
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 22
# NUMBER OF STATES: 100 2 2 87 7663
# E0 = -13.9973156182
# ITER = 22 ENTROPY = 0.815422521057
# -------------------------------------------
# Truncation error = 8.31709811873e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 23
# NUMBER OF STATES: 100 2 2 87 7757
# E0 = -13.9973156182
# ITER = 23 ENTROPY = 0.660528089267
# -------------------------------------------
# Truncation error = -9.99043425307e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 24
# NUMBER OF STATES: 100 2 2 64 5462
# E0 = -13.9973156182
# ITER = 24 ENTROPY = 0.79669341573
# -------------------------------------------
# Truncation error = -7.58610476493e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 25
# NUMBER OF STATES: 100 2 2 32 2814
# E0 = -13.9973156182
# ITER = 25 ENTROPY = 0.617384449455
# -------------------------------------------
# Truncation error = -8.34048899514e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 26
# NUMBER OF STATES: 100 2 2 16 1451
# E0 = -13.9973156182
# ITER = 26 ENTROPY = 0.770918506374
# -------------------------------------------
# Truncation error = 1.1637233666e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 27
# NUMBER OF STATES: 100 2 2 8 764
# E0 = -13.9973156182
# ITER = 27 ENTROPY = 0.550126608837
# -------------------------------------------
# Truncation error = -4.54872574543e-16
# -------------------------------------------
# LEFT-TO-RIGHT ITERATION 28
# NUMBER OF STATES: 100 2 2 4 407
# E0 = -13.9973156182
# ITER = 28 ENTROPY = 0.7364447087
# -------------------------------------------
# Truncation error = -5.59990422089e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 1
# NUMBER OF STATES: 100 2 2 2 222
# E0 = -13.9973156182
# ITER = 1 ENTROPY = 0.427266792483
# -------------------------------------------
# Truncation error = 1.11022302463e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 2
# NUMBER OF STATES: 100 2 2 4 407
# E0 = -13.9973156182
# ITER = 2 ENTROPY = 0.7364447087
# -------------------------------------------
# Truncation error = 9.89334482393e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 3
# NUMBER OF STATES: 100 2 2 8 764
# E0 = -13.9973156182
# ITER = 3 ENTROPY = 0.550126608846
# -------------------------------------------
# Truncation error = 3.8119299011e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 4
# NUMBER OF STATES: 100 2 2 16 1451
# E0 = -13.9973156182
# ITER = 4 ENTROPY = 0.770918506398
# -------------------------------------------
# Truncation error = 2.02861528021e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 5
# NUMBER OF STATES: 100 2 2 32 2814
# E0 = -13.9973156182
# ITER = 5 ENTROPY = 0.617384449553
# -------------------------------------------
# Truncation error = -4.80066899831e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 6
# NUMBER OF STATES: 100 2 2 64 5462
# E0 = -13.9973156182
# ITER = 6 ENTROPY = 0.796693415834
# -------------------------------------------
# Truncation error = -4.52456278308e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 7
# NUMBER OF STATES: 100 2 2 100 8785
# E0 = -13.9973156182
# ITER = 7 ENTROPY = 0.66052808946
# -------------------------------------------
# Truncation error = -4.06650862929e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 8
# NUMBER OF STATES: 100 2 2 100 8816
# E0 = -13.9973156182
# ITER = 8 ENTROPY = 0.815422521247
# -------------------------------------------
# Truncation error = -6.69841437838e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 9
# NUMBER OF STATES: 100 2 2 100 9002
# E0 = -13.9973156182
# ITER = 9 ENTROPY = 0.689026944957
# -------------------------------------------
# Truncation error = 2.92384181825e-15
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 10
# NUMBER OF STATES: 100 2 2 100 8940
# E0 = -13.9973156182
# ITER = 10 ENTROPY = 0.828567577048
# -------------------------------------------
# Truncation error = 5.09309860671e-15
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 11
# NUMBER OF STATES: 100 2 2 100 9045
# E0 = -13.9973156182
# ITER = 11 ENTROPY = 0.707404753637
# -------------------------------------------
# Truncation error = 1.49351898944e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 12
# NUMBER OF STATES: 100 2 2 100 8940
# E0 = -13.9973156182
# ITER = 12 ENTROPY = 0.836949179398
# -------------------------------------------
# Truncation error = 1.89513883662e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 13
# NUMBER OF STATES: 100 2 2 100 9045
# E0 = -13.9973156182
# ITER = 13 ENTROPY = 0.717770126361
# -------------------------------------------
# Truncation error = 3.43693252781e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 14
# NUMBER OF STATES: 100 2 2 100 8940
# E0 = -13.9973156182
# ITER = 14 ENTROPY = 0.841033951065
# -------------------------------------------
# Truncation error = 3.4281225457e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 15
# NUMBER OF STATES: 100 2 2 100 9002
# E0 = -13.9973156182
# ITER = 15 ENTROPY = 0.721125546401
# -------------------------------------------
# Truncation error = 4.4392188061e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 16
# NUMBER OF STATES: 100 2 2 100 8940
# E0 = -13.9973156182
# ITER = 16 ENTROPY = 0.84103395107
# -------------------------------------------
# Truncation error = 3.45606650988e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 17
# NUMBER OF STATES: 100 2 2 100 9002
# E0 = -13.9973156182
# ITER = 17 ENTROPY = 0.717770126372
# -------------------------------------------
# Truncation error = 3.38086007173e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 18
# NUMBER OF STATES: 100 2 2 100 8940
# E0 = -13.9973156182
# ITER = 18 ENTROPY = 0.83694917941
# -------------------------------------------
# Truncation error = 2.01121625111e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 19
# NUMBER OF STATES: 100 2 2 100 9002
# E0 = -13.9973156182
# ITER = 19 ENTROPY = 0.707404753654
# -------------------------------------------
# Truncation error = 1.53135179419e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 20
# NUMBER OF STATES: 100 2 2 100 8940
# E0 = -13.9973156182
# ITER = 20 ENTROPY = 0.828567577063
# -------------------------------------------
# Truncation error = 4.95430808632e-15
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 21
# NUMBER OF STATES: 100 2 2 100 9002
# E0 = -13.9973156182
# ITER = 21 ENTROPY = 0.689026944975
# -------------------------------------------
# Truncation error = 2.2315243051e-15
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 22
# NUMBER OF STATES: 100 2 2 100 8816
# E0 = -13.9973156182
# ITER = 22 ENTROPY = 0.81542252126
# -------------------------------------------
# Truncation error = -2.25462733902e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 23
# NUMBER OF STATES: 100 2 2 100 8785
# E0 = -13.9973156182
# ITER = 23 ENTROPY = 0.660528089475
# -------------------------------------------
# Truncation error = -3.37706903343e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 24
# NUMBER OF STATES: 64 2 2 100 5448
# E0 = -13.9973156182
# ITER = 24 ENTROPY = 0.796693415843
# -------------------------------------------
# Truncation error = -5.75974549536e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 25
# NUMBER OF STATES: 32 2 2 100 2814
# E0 = -13.9973156182
# ITER = 25 ENTROPY = 0.617384449565
# -------------------------------------------
# Truncation error = -4.52007736252e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 26
# NUMBER OF STATES: 16 2 2 100 1447
# E0 = -13.9973156182
# ITER = 26 ENTROPY = 0.770918506405
# -------------------------------------------
# Truncation error = -6.80530871856e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 27
# NUMBER OF STATES: 8 2 2 100 763
# E0 = -13.9973156182
# ITER = 27 ENTROPY = 0.550126608857
# -------------------------------------------
# Truncation error = -1.62508564887e-18
# -------------------------------------------
# FINAL SWEEP ITERATION
# RIGHT-TO-LEFT ITERATION 28
# NUMBER OF STATES: 4 2 2 100 412
# E0 = -13.9973156182
# ITER = 28 ENTROPY = 0.736444708703
# -------------------------------------------
# Truncation error = -4.64905891562e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 1
# NUMBER OF STATES: 2 2 2 100 225
# E0 = -13.9973156182
# ITER = 1 ENTROPY = 0.427266792487
# -------------------------------------------
# Truncation error = -4.16333634234e-17
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 2
# NUMBER OF STATES: 4 2 2 100 412
# E0 = -13.9973156182
# ITER = 2 ENTROPY = 0.736444708703
# -------------------------------------------
# Truncation error = -1.08528637466e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 3
# NUMBER OF STATES: 8 2 2 100 763
# E0 = -13.9973156182
# ITER = 3 ENTROPY = 0.550126608858
# -------------------------------------------
# Truncation error = 2.99670833497e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 4
# NUMBER OF STATES: 16 2 2 100 1447
# E0 = -13.9973156182
# ITER = 4 ENTROPY = 0.770918506406
# -------------------------------------------
# Truncation error = -1.67181923628e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 5
# NUMBER OF STATES: 32 2 2 100 2814
# E0 = -13.9973156182
# ITER = 5 ENTROPY = 0.617384449573
# -------------------------------------------
# Truncation error = -9.4145027773e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 6
# NUMBER OF STATES: 64 2 2 100 5448
# E0 = -13.9973156182
# ITER = 6 ENTROPY = 0.796693415851
# -------------------------------------------
# Truncation error = -3.9884822022e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 7
# NUMBER OF STATES: 100 2 2 100 8785
# E0 = -13.9973156182
# ITER = 7 ENTROPY = 0.660528089489
# -------------------------------------------
# Truncation error = -6.93013370827e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 8
# NUMBER OF STATES: 100 2 2 100 8816
# E0 = -13.9973156182
# ITER = 8 ENTROPY = 0.815422521273
# -------------------------------------------
# Truncation error = 4.1503762285e-16
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 9
# NUMBER OF STATES: 100 2 2 100 9002
# E0 = -13.9973156182
# ITER = 9 ENTROPY = 0.689026944996
# -------------------------------------------
# Truncation error = 2.22138673051e-15
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 10
# NUMBER OF STATES: 100 2 2 100 8940
# E0 = -13.9973156182
# ITER = 10 ENTROPY = 0.828567577082
# -------------------------------------------
# Truncation error = 4.51129532754e-15
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 11
# NUMBER OF STATES: 100 2 2 100 9088
# E0 = -13.9973156182
# ITER = 11 ENTROPY = 0.707404753683
# -------------------------------------------
# Truncation error = 1.74395928786e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 12
# NUMBER OF STATES: 100 2 2 100 8940
# E0 = -13.9973156182
# ITER = 12 ENTROPY = 0.836949179434
# -------------------------------------------
# Truncation error = 2.06612296635e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 13
# NUMBER OF STATES: 100 2 2 100 9002
# E0 = -13.9973156182
# ITER = 13 ENTROPY = 0.717770126407
# -------------------------------------------
# Truncation error = 3.3988384761e-14
# -------------------------------------------
# FINAL SWEEP ITERATION
# LEFT-TO-RIGHT ITERATION 14
# NUMBER OF STATES: 100 2 2 100 8940
# E0 = -13.9973156182
# ITER = 14 ENTROPY = 0.841033951099
# -------------------------------------------
# Truncation error = 3.42521187656e-14
# -------------------------------------------
# FINAL SWEEP - LAST ITERATION
# NUMBER OF STATES: 100 2 2 100 9002
# E0 = -13.9973156182
# ITER = 15 ENTROPY = 0.721125546444
# -------------------------------------------
# Truncation error = 4.36802852551e-14
# -------------------------------------------
# Checking if it is finished: not yet, next check in 60 seconds ( 0% done).
# Halted Simulation 1
# This task took 2 seconds.
# Checkpointing Simulation 1
# Finished with everything.

# %% [markdown]
# Next, we load the properties of the ground state measured by the DMRG code

# %%
data = pyalps.loadEigenstateMeasurements(pyalps.getResultFiles(prefix='parm_spin_one_half'))

# %% [markdown]
# and print them to the terminal.

# %%
for s in data[0]:
    print(s.props['observable'], ' : ', s.y[0])
# Out:
# Energy  :  -13.997315618223315
# Truncation error  :  4.368028525511696e-14

# %% [markdown]
# Additionally, we can load detailed data for each iteration step.

# %%
iter = pyalps.loadMeasurements(pyalps.getResultFiles(prefix='parm_spin_one_half'),
                          what=['Iteration Energy','Iteration Truncation Error'])

# %% [markdown]
# The above allows us to look at how the DMRG algorithm converged to the final results.
#
# We finally plot the convergence of the ground state energy and the truncation error as functions of iterations.

# %%
plt.figure()
pyalps.plot.plot(iter[0][0])
plt.title('Iteration history of ground state energy (S=1/2)')
plt.ylim(-15,0)
plt.ylabel('$E_0$')
plt.xlabel('iteration')

plt.figure()
pyalps.plot.plot(iter[0][1])
plt.title('Iteration history of truncation error (S=1/2)')
plt.yscale('log')
plt.ylabel('error')
plt.xlabel('iteration')

plt.show()
